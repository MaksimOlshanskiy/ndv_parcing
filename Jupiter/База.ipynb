# %%
import pandas as pd
import numpy as np

# %%
baza = pd.read_excel("04-05.2025_РЫНОК_типология_fixed.xlsx")

# %%
baza
# Out:
#        Дата обновления Название проекта на англ промзона Местоположение  \
# 0           2025-05-01      1-й Донской     NaN      NaN       МО ближ.
# 1           2025-05-01      1-й Донской     NaN      NaN       МО ближ.
# 2           2025-05-01      1-й Донской     NaN      NaN       МО ближ.
# 3           2025-05-01      1-й Донской     NaN      NaN       МО ближ.
# 4           2025-05-01      1-й Донской     NaN      NaN       МО ближ.
# ...                ...              ...     ...      ...            ...
# 211954      2025-04-01     Времена года     NaN      NaN       МО сред.
# 211955      2025-04-01     Времена года     NaN      NaN       МО сред.
# 211956      2025-04-01     Времена года     NaN      NaN       МО сред.
# 211957      2025-04-01     Времена года     NaN      NaN       МО сред.
# 211958      2025-04-01     Времена года     NaN      NaN       МО сред.
#
#             Метро Расстояние до метро, км Время до метро, мин МЦК/МЦД/БКЛ  \
# ...

# %%
baza = baza[(baza['Дата обновления'].dt.month == 5) & (baza['Дата обновления'].dt.year == 2025)]

# %%
baza
# Out:
#        Дата обновления Название проекта на англ        промзона  \
# 0           2025-05-01      1-й Донской     NaN             NaN
# 1           2025-05-01      1-й Донской     NaN             NaN
# 2           2025-05-01      1-й Донской     NaN             NaN
# 3           2025-05-01      1-й Донской     NaN             NaN
# 4           2025-05-01      1-й Донской     NaN             NaN
# ...                ...              ...     ...             ...
# 209786      2025-05-01             DIUS    Dius  нежилые здания
# 209787      2025-05-01             DIUS    Dius  нежилые здания
# 209788      2025-05-01             DIUS    Dius  нежилые здания
# 209789      2025-05-01             DIUS    Dius  нежилые здания
# 209790      2025-05-01             DIUS    Dius  нежилые здания
#
#        Местоположение     Метро Расстояние до метро, км Время до метро, мин  \
# 0            МО ближ.       NaN                     NaN                 NaN
# ...

# %%
ger = baza[baza['Название проекта'] == 'Рига Хиллс']

# %%
ger
# Out:
#       Дата обновления Название проекта на англ промзона Местоположение Метро  \
# 91965      2025-05-01       Рига Хиллс     NaN      NaN       МО ближ.   NaN
# 91966      2025-05-01       Рига Хиллс     NaN      NaN       МО ближ.   NaN
# 91967      2025-05-01       Рига Хиллс     NaN      NaN       МО ближ.   NaN
# 91968      2025-05-01       Рига Хиллс     NaN      NaN       МО ближ.   NaN
# 91969      2025-05-01       Рига Хиллс     NaN      NaN       МО ближ.   NaN
# ...               ...              ...     ...      ...            ...   ...
# 92768      2025-05-01       Рига Хиллс     NaN      NaN       МО ближ.   NaN
# 92769      2025-05-01       Рига Хиллс     NaN      NaN       МО ближ.   NaN
# 92770      2025-05-01       Рига Хиллс     NaN      NaN       МО ближ.   NaN
# 92771      2025-05-01       Рига Хиллс     NaN      NaN       МО ближ.   NaN
# 92772      2025-05-01       Рига Хиллс     NaN      NaN       МО ближ.   NaN
#
# ...

# %%
duplicates = vost[vost.duplicated(keep=False)]
print(duplicates)
# Out:
#       Дата обновления Название проекта на англ промзона Местоположение Метро  \
# 38863      2025-05-01        Восточный     NaN      NaN       МО ближ.   NaN
# 38864      2025-05-01        Восточный     NaN      NaN       МО ближ.   NaN
# 38865      2025-05-01        Восточный     NaN      NaN       МО ближ.   NaN
# 38868      2025-05-01        Восточный     NaN      NaN       МО ближ.   NaN
# 38870      2025-05-01        Восточный     NaN      NaN       МО ближ.   NaN
# ...               ...              ...     ...      ...            ...   ...
# 39042      2025-05-01        Восточный     NaN      NaN       МО ближ.   NaN
# 39043      2025-05-01        Восточный     NaN      NaN       МО ближ.   NaN
# 39044      2025-05-01        Восточный     NaN      NaN       МО ближ.   NaN
# 39045      2025-05-01        Восточный     NaN      NaN       МО ближ.   NaN
# 39046      2025-05-01        Восточный     NaN      NaN       МО ближ.   NaN
#
# ...

# %%
ger.duplicated().sum()
# Out:
# np.int64(517)

# %%
duna_no_first_duplicates = ger[ger.duplicated(keep='first')]

# %%
duna_no_first_duplicates
# Out:
#       Дата обновления Название проекта на англ промзона Местоположение Метро  \
# 91971      2025-05-01       Рига Хиллс     NaN      NaN       МО ближ.   NaN
# 91975      2025-05-01       Рига Хиллс     NaN      NaN       МО ближ.   NaN
# 91980      2025-05-01       Рига Хиллс     NaN      NaN       МО ближ.   NaN
# 91983      2025-05-01       Рига Хиллс     NaN      NaN       МО ближ.   NaN
# 91985      2025-05-01       Рига Хиллс     NaN      NaN       МО ближ.   NaN
# ...               ...              ...     ...      ...            ...   ...
# 92768      2025-05-01       Рига Хиллс     NaN      NaN       МО ближ.   NaN
# 92769      2025-05-01       Рига Хиллс     NaN      NaN       МО ближ.   NaN
# 92770      2025-05-01       Рига Хиллс     NaN      NaN       МО ближ.   NaN
# 92771      2025-05-01       Рига Хиллс     NaN      NaN       МО ближ.   NaN
# 92772      2025-05-01       Рига Хиллс     NaN      NaN       МО ближ.   NaN
#
# ...

# %%
duna_no_first_duplicates.to_excel("duna_no_first_duplicatesy.xlsx")
