# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"\\192.168.252.25\аналитики\ОТЧЕТЫ\База проектов.xlsx")

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 688 entries, 0 to 687
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id_x                       0 non-null      float64
#  1   Название проекта           688 non-null    object
#  2   На англ                    165 non-null    object
#  3   Промзона                   265 non-null    object
#  4   Местоположение             680 non-null    object
#  5   Метро                      680 non-null    object
#  6   Расстояние до метро, км    680 non-null    object
#  7   Время до метро, мин        680 non-null    object
#  8   МЦК/МЦД/БКЛ                680 non-null    object
#  9   Расстояние до МЦК/МЦД, км  679 non-null    object
#  10  Время до МЦК/МЦД, мин      674 non-null    object
#  11  БКЛ                        678 non-null    object
#  12  Расстояние до БКЛ, км      678 non-null    object
# ...

# %%
df2 = pd.read_excel(r"C:\Users\m.olshanskiy\Desktop\Пыпин - База.xlsx")

# %%
merged = df.merge(df2, how = 'outer', on = 'Название проекта')

# %%
merged.to_excel(r"C:\Users\m.olshanskiy\Desktop\Пыпин - База2.xlsx", index=False)

# %%
# Значения из df1, которых нет в df2
missing_in_df2 = merged[~merged['Название проекта'].isin(df['Название проекта'])]

# %%
merged
# Out:
#      id_x                   Название проекта На англ  \
# 0     NaN                        1-й Донской     NaN
# 1     NaN                   1-й Измайловский     NaN
# 2     NaN                  1-й Ленинградский     NaN
# 3     NaN                  1-й Лермонтовский     NaN
# 4     NaN                   1-й Саларьевский     NaN
# ..    ...                                ...     ...
# 683   NaN                          Яуза парк     NaN
# 684   NaN  д. Марушкино, Северная ул., д. 21     NaN
# 685   NaN             п. Знамя Октября, д. 3     NaN
# 686   NaN               п. Шишкин лес, д. 21     NaN
# 687   NaN                   по ул. Макаренко     NaN
#
#                         Промзона Местоположение         Метро  \
# 0    свободный земельный участок       МО ближ.           нет
# 1                       промзона       ТТК/МКАД  Черкизовская
# 2                       промзона        за МКАД           нет
# 3                            NaN       МО ближ.           нет
# ...
