# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel("2023 Новая Москва/03-04.2023_МО.xlsx", sheet_name="массив")

# %%
df1
# Out:
#       Дата обновления   Название проекта  на англ промзона Местоположение  \
# 0          2023-03-01         Гоголь парк     NaN      NaN       МО ближ.
# 1          2023-03-01         Гоголь парк     NaN      NaN       МО ближ.
# 2          2023-03-01         Гоголь парк     NaN      NaN       МО ближ.
# 3          2023-03-01         Гоголь парк     NaN      NaN       МО ближ.
# 4          2023-03-01         Гоголь парк     NaN      NaN       МО ближ.
# ...               ...                 ...     ...      ...            ...
# 64131      2023-04-01  1-й Шереметьевский     NaN      NaN       МО ближ.
# 64132      2023-04-01  1-й Шереметьевский     NaN      NaN       МО ближ.
# 64133      2023-04-01  1-й Шереметьевский     NaN      NaN       МО ближ.
# 64134      2023-04-01  1-й Шереметьевский     NaN      NaN       МО ближ.
# 64135      2023-04-01  1-й Шереметьевский     NaN      NaN       МО ближ.
#
#               Метро Расстояние до метро, км Время до метро, мин МЦК/МЦД/БКЛ  \
# ...

# %%
df1['Дата обновления'] = pd.to_datetime('1899-12-30') + pd.to_timedelta(df1['Дата обновления'], unit='D')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[155], line 1
# ----> 1 df1['Дата обновления'] = pd.to_datetime('1899-12-30') + pd.to_timedelta(df1['Дата обновления'], unit='D')
#
# File ~\PycharmProjects\ndv_parsing\.venv\Lib\site-packages\pandas\core\tools\timedeltas.py:201, in to_timedelta(arg, unit, errors)
#     199     return arg
#     200 elif isinstance(arg, ABCSeries):
# --> 201     values = _convert_listlike(arg._values, unit=unit, errors=errors)
#     202     return arg._constructor(values, index=arg.index, name=arg.name)
#     203 elif isinstance(arg, ABCIndex):
#
# File ~\PycharmProjects\ndv_parsing\.venv\Lib\site-packages\pandas\core\tools\timedeltas.py:266, in _convert_listlike(arg, unit, errors, name)
#     263     return arg
#     265 try:
# --> 266     td64arr = sequence_to_td64ns(arg, unit=unit, errors=errors, copy=False)[0]
# ...

# %%
df1 = df1[(df1['Дата обновления'].dt.month == 3) & (df1['Дата обновления'].dt.year == 2023)]

# %%
df1.to_excel("2023 Новая Москва/03-04.2023_МО.xlsx")
