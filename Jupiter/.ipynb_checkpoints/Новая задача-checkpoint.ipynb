# %%
import pandas as pd
from openpyxl import load_workbook
from openpyxl.utils import get_column_letter
from openpyxl.styles import Alignment
import datetime
import locale
locale.setlocale(locale.LC_TIME, 'ru_RU.UTF-8')
# Out:
# 'ru_RU.UTF-8'

# %%
# Словарь месяцев вручную, чтобы избежать проблем с кодировкой
months_ru = {
    1: "янв", 2: "фев", 3: "мар", 4: "апр", 5: "май", 6: "июн",
    7: "июл", 8: "авг", 9: "сен", 10: "окт", 11: "ноя", 12: "дек"
}

# %%
df = pd.read_excel(r"C:\Users\m.olshanskiy\Desktop\Продажи отсортированные.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Застройщик  234 non-null    object
#  1   Indicators  160 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 3.8+ KB

# %%
df
# Out:
#              Застройщик  Indicators
# 0                   ПИК      1587.0
# 1               Самолет      1534.0
# 2     ДСК-1 (ФСК Лидер)       543.0
# 3              MR Group       499.0
# 4                  А101       487.0
# ..                  ...         ...
# 229             Gravion         NaN
# 230              Glorax         NaN
# 231   Engeo Development         NaN
# 232  Author Development         NaN
# 233     Ant Development         NaN
#
# [234 rows x 2 columns]

# %%
developers = df["Застройщик"].tolist()

# %%
developers
# Out:
# ['ПИК',
#  'Самолет',
#  'ДСК-1 (ФСК Лидер)',
#  'MR Group',
#  'А101',
#  'Гранель',
#  'Брусника',
#  'ЛСР',
#  'Эталон',
#  'Level Group',
#  'Plus Development',
#  'Донстрой',
#  'Dogma',
#  'Аквилон',
#  'ФСК',
#  'Главстрой',
#  'Страна',
#  'Абсолют',
#  'Основа',
#  'РГ Девелопмент',
#  'Sminex',
#  'Родина',
#  '3S Development',
#  'Профи Инвест',
#  'Корона',
#  'Пионер',
#  'Отрада Девелопмент',
#  'КОРТРОС',
#  'ПИК (Forma)',
#  'Галс Девелопмент',
#  'Московский фонд реновации',
#  'Горакс',
#  'ГК Регионы',
#  'Stone',
#  'Сбербанк',
#  'Альфастройинвест',
#  'Пик (Среда)',
#  'Tekta',
#  'Инвесттраст (Рост)',
#  'Мангазея Девелопмент',
#  'Град',
#  'УЭЗ',
#  'Крост',
#  'Талан',
#  'Unikey',
#  'Стройинновация',
#  'Asterus Development',
#  'Русич',
#  'Зеленый сад',
#  'Dar Development',
#  'СЗ ЖК Яркий',
#  'Upside Development (СМУ-6)',
#  'Ikon Development',
#  'Рос Евро Сити',
#  'Мособлжилстрой',
#  'Дело',
#  'BTR Group',
#  'AFI Development',
#  'Тройка РЭД',
# ...

# %%
df2 = pd.read_excel(r"C:\Users\m.olshanskiy\Desktop\Таблица с продажами.xlsx")

# %%
df_sorted
# Out:
#         №       Застройщик  Регион            Название ЖК  \
# 0       №       Застройщик  Регион            Название ЖК
# 1       1              ПИК   Total                    NaN
# 2       1              ПИК  Москва                  Total
# 3       1              ПИК  Москва       Бусиновский парк
# 4       1              ПИК  Москва        Люблинский парк
# ...   ...              ...     ...                    ...
# 1310  234  Ant Development  Москва  Виктори Парк Резиденс
# 1311    №       Застройщик  Регион            Название ЖК
# 1312  234  Ant Development   Total                    NaN
# 1313  234  Ant Development  Москва                  Total
# 1314  234  Ant Development  Москва  Виктори Парк Резиденс
#
#       2025-01-01 00:00:00  2025-02-01 00:00:00  2025-03-01 00:00:00  \
# 0     2025-01-01 00:00:00  2025-02-01 00:00:00  2025-03-01 00:00:00
# 1                  3055.0               4417.0               3772.0
# ...

# %%
def format_col(col):
    if isinstance(col, (pd.Timestamp, datetime.datetime)):
        return f"{months_ru[col.month]}.{str(col.year)[-2:]}"
    return col

df2.columns = [format_col(col) for col in df2.columns]

# %%
# Проверяем результат
print(df2.columns.tolist())
# Out:
# ['Застройщик', 'Регион', 'Название ЖК', 'янв.25', 'фев.25', 'мар.25', 'апр.25', 'май.25', 'июн.25', 'июл.25', 'авг.25', 'сен.25', 'окт.25', 'Total']

# %%
region_order = ['Total', 'Москва', 'Новая Москва', 'Московская область']

# %%
df2['Застройщик'] = pd.Categorical(df2['Застройщик'], categories=developers, ordered=True)
df2['Регион'] = pd.Categorical(df2['Регион'], categories=region_order, ordered=True)
df_sorted = df2.sort_values(['Застройщик', 'Регион']).reset_index(drop=True)

# %%
# Пусть df_sorted — это уже отсортированная таблица

# Список уникальных застройщиков в порядке сортировки
for dev in df_sorted['Застройщик'].unique():
    temp = df_sorted[df_sorted['Застройщик'] == dev]
    
    # Добавляем строку-шапку
    header_row = pd.DataFrame([df_sorted.columns], columns=df_sorted.columns)
    df2.columns = [format_col(col) for col in df2.columns]
    
    
    # Добавляем в общий DataFrame: сначала шапку, потом блок застройщика
    df_sorted = pd.concat([df_out, header_row, temp], ignore_index=True)

# %%
# --- 3. Сохраняем в Excel ---
output_file = r"C:\Users\m.olshanskiy\Desktop\Продажи отсортированные2.xlsx"
df_sorted.to_excel(output_file, index=False)

# --- 4. Объединяем ячейки в Excel ---
wb = load_workbook(output_file)
ws = wb.active

# Функция объединения одинаковых подряд ячеек в столбце
def merge_identical_cells(column_idx):
    start = 2  # пропускаем заголовок
    current_value = ws[f"{get_column_letter(column_idx)}{start}"].value
    for row in range(3, ws.max_row + 2):
        cell_value = ws[f"{get_column_letter(column_idx)}{row}"].value
        if cell_value != current_value:
            if row - start > 1 and current_value is not None:
                ws.merge_cells(start_row=start, start_column=column_idx,
                               end_row=row - 1, end_column=column_idx)
                ws[f"{get_column_letter(column_idx)}{start}"].alignment = Alignment(
                    vertical="center", horizontal="center")
            start = row
            current_value = cell_value

# Объединяем ячейки по столбцам: 1 — Застройщик, 2 — Регион
merge_identical_cells(1)
merge_identical_cells(2)
merge_identical_cells(3)

wb.save(output_file)
print("✅ Готово! Ячейки объединены и выровнены по центру.")
# Out:
# ✅ Готово! Ячейки объединены и выровнены по центру.

# %%
df_sorted.to_excel(r"C:\Users\m.olshanskiy\Desktop\Продажи отсортированные2.xlsx", index=False)
