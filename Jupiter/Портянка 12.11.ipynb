# %%
import pandas as pd
from openpyxl import load_workbook
from openpyxl.styles import Font, PatternFill, Alignment
from openpyxl.utils import get_column_letter
import datetime
import locale
locale.setlocale(locale.LC_TIME, 'ru_RU.UTF-8')
from io import BytesIO

# %%
# Словарь месяцев вручную, чтобы избежать проблем с кодировкой
months_ru = {
    1: "янв", 2: "фев", 3: "мар", 4: "апр", 5: "май", 6: "июн",
    7: "июл", 8: "авг", 9: "сен", 10: "окт", 11: "ноя", 12: "дек"
}

# %%
df = pd.read_excel(r"C:\Users\m.olshanskiy\Desktop\112025_Продажи за октябрь.xlsx", sheet_name = 'рейтинг')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Застройщик  236 non-null    object
#  1   Indicators  164 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 3.8+ KB

# %%
df
# Out:
#             Застройщик  Indicators
# 0              Самолет      1958.0
# 1                  ПИК      1770.0
# 2                 А101       683.0
# 3    ДСК-1 (ФСК Лидер)       582.0
# 4              Гранель       546.0
# ..                 ...         ...
# 231            Бэсткон         NaN
# 232  Инвестстройрегион         NaN
# 233           Меджиком         NaN
# 234                ПСТ         NaN
# 235  СК Олимпийский 10         NaN
#
# [236 rows x 2 columns]

# %%
developers = df["Застройщик"].tolist()

# %%
df2 = pd.read_excel(r"C:\Users\m.olshanskiy\Desktop\112025_Продажи за октябрь.xlsx", sheet_name = 'массив')

# %%
def format_col(col):
    if isinstance(col, (pd.Timestamp, datetime.datetime)):
        return f"{months_ru[col.month]}.{str(col.year)[-2:]}"
    return col

df2.columns = [format_col(col) for col in df2.columns]

# %%
# Фильтруем по каждому региону
def remove_total_if_one_jk(group):
    # Проверяем сколько строк с ЖК (не Total)
    jk_count = group[group["Название ЖК"] != "Total"].shape[0]
    if jk_count <= 1:
        # Удаляем строки с Total
        group = group[group["Название ЖК"] != "Total"]
    return group

# %%
# Проверяем результат
print(df2.columns.tolist())
# Out:
# ['№', 'Застройщик', 'Регион', 'Название ЖК', 'Среднее за 2024 г., шт', 'янв.25', 'фев.25', 'мар.25', 'апр.25', 'май.25', 'июн.25', 'июл.25', 'авг.25', 'сен.25', 'окт.25', 'Среднее за 2025 г., шт']

# %%
region_order = ['Total', 'Москва', 'Новая Москва', 'Московская область']

# %%
# 2. Создаём словарь: застройщик → порядковый номер
developer_numbers = {name: i + 1 for i, name in enumerate(df["Застройщик"].dropna().unique())}

# 3. Добавляем новый столбец с номерами
df2["№"] = df2["Застройщик"].map(developer_numbers)

# 4. Ставим столбец "№" в начало
df2 = df2[["№"] + [col for col in df2.columns if col != "№"]]

# %%
df2['Застройщик'] = pd.Categorical(df2['Застройщик'], categories=developers, ordered=True)
df2['Регион'] = pd.Categorical(df2['Регион'], categories=region_order, ordered=True)
df_sorted = df2.sort_values(['Застройщик', 'Регион']).reset_index(drop=True)

# 5. Дублируем шапку перед каждым застройщиком
header = pd.DataFrame([df_sorted.columns], columns=df_sorted.columns)  # создаём строку-шапку
result = pd.DataFrame(columns=df_sorted.columns)

for dev in df_sorted["№"].unique():
    block = df_sorted[df_sorted["№"] == dev]
    result = pd.concat([result, header, block], ignore_index=True)

df_sorted = result

# 5. Заменяем все значения "Total" на "Итого"
# df_sorted = df_sorted.replace("Total", "Итого")

df_cleaned = df_sorted.groupby("Регион", group_keys=False).apply(remove_total_if_one_jk)
# Out:
# C:\Users\m.olshanskiy\AppData\Local\Temp\ipykernel_2384\2155248353.py:18: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_cleaned = df_sorted.groupby("Регион", group_keys=False).apply(remove_total_if_one_jk)

# %%
df_sorted = df_cleaned

# %%
# --- 2. Сохраняем в Excel ---
output_file = r"C:\Users\m.olshanskiy\Desktop\Продажи отсортированные 12.11-2.xlsx"
df_sorted.to_excel(output_file, index=False)

# --- 3. Открываем для форматирования ---
wb = load_workbook(output_file)
ws = wb.active

# Эта часть удаляет строки Total там, где в регионе всего один проект

region_start = None
region_end = None
current_region = None
rows_to_delete = []

for row in range(2, ws.max_row + 1):  # первая строка — заголовок
    region = ws[f"C{row}"].value  # теперь регион в колонке C
    jk_name = ws[f"D{row}"].value  # Total / ЖК в колонке D

    if region is None:
        continue
    if jk_name is None:
        jk_name = ""

    if region != current_region:
        if region_start is not None:
            # Собираем все названия ЖК в регионе
            jk_list = [str(ws[f"D{r}"].value).strip() for r in range(region_start, region_end + 1)]
            total_count = sum(1 for name in jk_list if name.lower() == "total")
            real_jk_count = sum(1 for name in jk_list if name.lower() != "total")

            print(f"\nРегион: {current_region}")
            print(f"Список ЖК (включая Total): {jk_list}")
            print(f"Количество ЖК без Total: {real_jk_count}, Total: {total_count}")

            # Если ЖК всего 1, удаляем Total
            if real_jk_count == 1 and total_count > 0:
                for r in range(region_start, region_end + 1):
                    if str(ws[f"D{r}"].value).strip().lower() == "total":
                        rows_to_delete.append(r)
                        print(f"Удаляю строку {r} с 'Total'")

        current_region = region
        region_start = row

    region_end = row

# Проверяем последний регион
if region_start is not None:
    jk_list = [str(ws[f"D{r}"].value).strip() for r in range(region_start, region_end + 1)]
    total_count = sum(1 for name in jk_list if name.lower() == "total")
    real_jk_count = sum(1 for name in jk_list if name.lower() != "total")

    print(f"\nРегион: {current_region}")
    print(f"Список ЖК (включая Total): {jk_list}")
    print(f"Количество ЖК без Total: {real_jk_count}, Total: {total_count}")

    if real_jk_count == 1 and total_count > 0:
        for r in range(region_start, region_end + 1):
            if str(ws[f"D{r}"].value).strip().lower() == "total":
                rows_to_delete.append(r)
                print(f"Удаляю строку {r} с 'Total'")

# Удаляем строки с конца
for r in sorted(rows_to_delete, reverse=True):
    ws.delete_rows(r)

# Эта часть добавляет шапку для каждого застройщика, а также добавляет серую заливку и жирный шрифт

# Форматы
fill = PatternFill(start_color="D9D9D9", end_color="D9D9D9", fill_type="solid")
bold_font = Font(bold=True)
center_align = Alignment(vertical="center", horizontal="center")

# --- 4. Форматируем строки-шапки ---
for row in ws.iter_rows(min_row=1, max_row=ws.max_row):
    if row[0].value == "№":  # шапка начинается со "№"
        for cell in row:
            cell.font = bold_font
            cell.fill = fill
            cell.alignment = center_align

# --- 5. Объединяем одинаковые подряд ячейки ---
def merge_identical_cells(column_idx):
    start = 2  # пропускаем первую строку
    current_value = ws[f"{get_column_letter(column_idx)}{start}"].value
    for row in range(3, ws.max_row + 2):
        cell_value = ws[f"{get_column_letter(column_idx)}{row}"].value
        if cell_value != current_value:
            if row - start > 1 and current_value is not None:
                ws.merge_cells(start_row=start, start_column=column_idx,
                               end_row=row - 1, end_column=column_idx)
                ws[f"{get_column_letter(column_idx)}{start}"].alignment = center_align
            start = row
            current_value = cell_value

# Объединяем по нужным столбцам
merge_identical_cells(1)  # №
merge_identical_cells(2)  # Застройщик
merge_identical_cells(3)  # Регион
merge_identical_cells(4)  # Название ЖК (если нужно)




# --- 6. Сохраняем итог ---
wb.save(output_file)
print("✅ Готово! Шапки добавлены, выделены цветом, и ячейки объединены.")
# Out:
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Молжаниново', 'Квартал Домашний', 'Верейская 41', 'Октябрьская 98', 'Квартал на воде', 'Нова', 'Стремянный 2']
# Количество ЖК без Total: 7, Total: 1
#
# Регион: Новая Москва
# Список ЖК (включая Total): ['Total', 'Остафьево', 'Эко Бунино', 'Новое Внуково', 'Цветочные поляны Экопарк', 'Квартал Западный', 'Квартал Марьино', 'Тропарево Парк', 'Подольские кварталы', 'Алхимово', 'Цветочные поляны Сити', 'Квартал Румянцево', 'Ольховый квартал']
# Количество ЖК без Total: 12, Total: 1
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Пригород Лесное', 'Мытищи Парк', 'Новоград Павлино', 'Горки Парк', 'Новое Видное', 'Прибрежный парк', 'Рублевский квартал', 'Пятницкие луга', 'Квартал Ивакино', 'Томилино Парк', 'Егорово Парк', 'Богдановский Лес', 'Квартал Строгино', 'Квартал Авиаторов', 'Спутник', 'Большое Путилково', 'Долина Яузы', 'Космический квартал', 'Люберцы 2018-2023', 'Заречье Парк']
# Количество ЖК без Total: 20, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Бусиновский парк', 'Люблинский парк', 'Москворечье', 'Зеленый парк', 'Матвеевский парк', 'Плеханова 11', 'Большая Академическая 85', 'Холланд Парк', 'Алтуфьевское 53', 'Волжский парк', 'Никольские луга', 'Кавказский 51', 'Мичуринский парк', 'Второй Иртышский', 'Амурский Парк', 'Руставели 14', 'Второй Нагатинский', 'Полар', 'Митинский лес', 'Первый Дубровский', 'Барклая 6', 'Ютаново', 'Сигнальный 16', 'Кутузовский квартал', 'Новое Очаково', 'Кольская 8', 'Римского-Корсакова 11', 'Кронштадтский 9', 'Открытый парк', 'Большая Очаковская 2', 'Нарвин', 'Кронштадтский 14', 'Квартал Мит', 'Лосиноостровский парк', 'Полярная 25', 'Красноказарменная 15', 'Перовское 2', 'Вангарден']
# Количество ЖК без Total: 38, Total: 1
#
# Регион: Новая Москва
# Список ЖК (включая Total): ['Total', 'Саларьево Парк', 'Середневский лес', 'Юнино', 'Бунинские луга', 'Бунинская набережная']
# Количество ЖК без Total: 5, Total: 1
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Ильинские луга', 'Яуза Парк (Мытищи)', 'Ярославский квартал', 'Восточное Бутово', 'Белая Дача Парк', 'Ярославский', 'Одинцово-1', 'Томилинский бульвар', 'Кузьминский лес', 'Измайловский леc', 'Жулебино Парк']
# Количество ЖК без Total: 11, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Южные сады', 'Дом на Зорге']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Новая Москва
# Список ЖК (включая Total): ['Total', 'Бунинские кварталы', 'Прокшино', 'Дзен-Кварталы', 'Скандинавия Центр', 'Деснаречье', 'Скандинавия Юг', 'Родные кварталы']
# Количество ЖК без Total: 7, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Первый Измайловский', 'Первый Ленинградский']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Новая Москва
# Список ЖК (включая Total): ['Total', 'Первый Ясеневский', 'Первый Саларьевский']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Первый Южный', 'Первый Шереметьевский', 'Первый Донской', 'Первый Химкинский', 'Южная Битца', 'Первый Лермонтовский']
# Количество ЖК без Total: 6, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Би Лак', 'Май Приорити Басманный', 'Май Приорити Павелецкая', 'Тринити-3', 'Май Приорити Дубровка', 'Хайвэй', 'Май Приорити Мневники', 'Тринити', 'Май Приорити Нижегородская']
# Количество ЖК без Total: 9, Total: 1
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Ильинойс', 'Аникеевский', 'Новая Рига', 'Бригантина (Долгопрудный)', 'Пехра', 'Новая Алексеевская роща', 'Театральный парк', 'Живописный']
# Количество ЖК без Total: 8, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Квартал Метроном', 'Квартал Герцена', 'Издание', 'Монс', 'Дом А']
# Количество ЖК без Total: 5, Total: 1
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Первый квартал']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 162 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Сити Бэй', 'Ситизен', 'Сет', 'Джойс', 'Мод', 'Селигер Сити', 'Веер', 'Павелецкая Сити', 'Слава', 'Симфони 34', 'Метрополия', 'Мира', 'Фили Сити', 'Николь', 'Форум', 'Луче', 'Клос 17']
# Количество ЖК без Total: 17, Total: 1
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Эко Видное 2.0', 'Мыс']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Лучи-2', 'Зиларт', 'Вэйв', 'Дмитровское небо', 'Парк Сайд', 'Обручева 30', 'Марк', 'Ле Дом']
# Количество ЖК без Total: 8, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Сидней Сити', 'Скай Гарден', 'Амбер Сити', 'Роттердам', 'Архитектор', 'Лэйк', 'Режиссер']
# Количество ЖК без Total: 7, Total: 1
#
# Регион: Новая Москва
# Список ЖК (включая Total): ['Total', 'Движение Говорово']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 208 с 'Total'
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Римский', 'Жаворонки Клаб', 'Апрелевка Клаб']
# Количество ЖК без Total: 3, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Шагал', 'Воксхолл', 'Мариин Парк', 'СоколИнн']
# Количество ЖК без Total: 4, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Публицист', 'Эво']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Левел Южнопортовая', 'Левел Мичуринский', 'Левел Нижегородская', 'Левел Звенигородская', 'Левел Селигерская', 'Левел Бауманская', 'Левел Академическая', 'Левел Причальный', 'Левел Нагатинская', 'Левел Войковская', 'Левел Стрешнево', 'Саввинская 27', 'Саввинская 17']
# Количество ЖК без Total: 13, Total: 1
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Левел Лесной']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 242 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Остров', 'Символ', 'Событие', 'Большая Татарская 35', 'Река', 'Дом 22', 'Огни']
# Количество ЖК без Total: 7, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Баланс', 'Береговой', 'Новые Академики']
# Количество ЖК без Total: 3, Total: 1
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Квартал героев', 'Столичный']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Лайф Тайм', 'Тишинский бульвар', 'Достижение', 'Форивер', 'Фрунзенская набережная', 'Лаврушинский', 'Обыденский 1', 'Чистые пруды', 'Ильинка 3/8', 'Форивер Резиденс']
# Количество ЖК без Total: 10, Total: 1
#
# Регион: Новая Москва
# Список ЖК (включая Total): ['Total', 'Филатов луг']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 276 с 'Total'
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Новое Пушкино', 'Белый Град', 'Новое Медведково', 'Одинград Семейный квартал', 'Миловидное']
# Количество ЖК без Total: 5, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Акценты']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 286 с 'Total'
#
# Регион: Новая Москва
# Список ЖК (включая Total): ['Total', 'Детали']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 288 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Страна Озерная', 'Репаблик', 'Страна Заречная', 'Вау']
# Количество ЖК без Total: 4, Total: 1
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Страна Парковая']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 297 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Коллекция Лужники']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 301 с 'Total'
#
# Регион: Новая Москва
# Список ЖК (включая Total): ['Total', 'Переделкино Ближнее', 'Первый Московский']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Резиденции Сколково']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 306 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Никольский квартал Отрада', 'Смарт Квартал Лесная отрада', 'Отрада на реке', 'Отрада Комфорт']
# Количество ЖК без Total: 4, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Аквилон Сигнал', 'Аквилон Бисайд', 'Инди Тауэрс', 'Аквилон Митино']
# Количество ЖК без Total: 4, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Мираполис', 'Наметкин Тауэр', 'Вэри', 'Эво Парк Сокольники', 'Эмоушн', 'Уно Соколиная гора', 'Эво Парк Измайлово', 'Уно Головинские пруды', 'Физтех Сити', 'Уно Горбунова', 'Ред 7']
# Количество ЖК без Total: 11, Total: 1
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Гоголь Парк']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 336 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Западная Ивантеевка', 'Фабрикант', 'Ривер Парк (Королев)', 'Новая Ивантеевка', 'Седьмое небо', '31-й квартал (Пушкино)', 'Дом на Студенческой', 'Поколение первых', 'Тургенева 9-13 (Пушкино)']
# Количество ЖК без Total: 9, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Дюна (Котельники)', 'Дюна Сити']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Тэйт', 'Ультима Сити', 'Ай Лав', 'Хэдлайнер']
# Количество ЖК без Total: 4, Total: 1
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Равновесие']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 362 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Сиреневый парк', 'Афи Тауэр', 'Афи Парк Воронцовский']
# Количество ЖК без Total: 3, Total: 1
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Одинбург']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 370 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Селигерская 32А (реновация)', 'Профсоюзная 60 (реновация)', 'Люблинская 52/1 (реновация)', 'Полярная 4 (реновация)', 'Кусковская 12 (реновация)']
# Количество ЖК без Total: 5, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Новая Москва
# Список ЖК (включая Total): ['Total', 'Новые Ватутинки Заречный', 'Новые Ватутинки', 'Новое Летово']
# Количество ЖК без Total: 3, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Войс Тауэрс']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 388 с 'Total'
#
# Регион: Новая Москва
# Список ЖК (включая Total): ['Total', 'Форвиль']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 390 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Айс Туэрс']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 394 с 'Total'
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Домодедово Парк Новый квартал', 'Химки Тайм', 'Родники (Раменский район)']
# Количество ЖК без Total: 3, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Каштановая роща']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 402 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Моментс', 'Соул', 'Портлэнд', 'Паве', 'Форст']
# Количество ЖК без Total: 5, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Михалковский', 'Варшавские ворота', 'Семеновский парк 2', 'Петровский парк 2', 'Родной Город. Октябрьское поле']
# Количество ЖК без Total: 5, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Союз', 'Родина Парк', 'Родина Переделкино']
# Количество ЖК без Total: 3, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Дрим Рива', 'Преображенская площадь']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Новотомилино', 'Видный берег 2', 'Облака 2.0']
# Количество ЖК без Total: 3, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Новая Москва
# Список ЖК (включая Total): ['Total', 'Смарт Гарден']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 439 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Московский (Подольск)']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 443 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Хай Лайф', 'Лайф Варшавская', 'Прайд', 'Шифт', 'Опус']
# Количество ЖК без Total: 5, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Твелв 12', 'Эвер', 'Эра']
# Количество ЖК без Total: 3, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Кит']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 461 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Малевич', 'Кристал', 'Театральный квартал', 'Высотка на Жукова']
# Количество ЖК без Total: 4, Total: 1
#
# Регион: Новая Москва
# Список ЖК (включая Total): ['Total', 'Новая Звезда']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 470 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Новая Москва
# Список ЖК (включая Total): ['Total', 'Новые смыслы']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 474 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Чкалов']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 478 с 'Total'
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Новый Зеленоград', 'Сколково Уан']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Грин Гарден']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 485 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Пушкиноград']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 489 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Планерный квартал']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 493 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Сберсити']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 497 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Алиа']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 501 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Русич Кантемировский']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 505 с 'Total'
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Новые Котельники']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 507 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Восточный (Звенигород)', 'Школьный (Подольск)']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Инджой']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 516 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Ракурс', 'Солос']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Мангазея на Речном', 'Назаре', 'Мангазея на Тульской', 'Интонация']
# Количество ЖК без Total: 4, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Рига Хиллс']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 532 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Дом 56 на Энгельса', 'Адмирал', 'Монблан', 'Космо 4/22', 'Рождественка 8']
# Количество ЖК без Total: 5, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Отрадный']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 544 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Апсайд Тауэрс', 'Клементин']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Шолохово', 'Южное Пушкино']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Волковская 67 (Люберцы)', 'Дом в Малаховке', 'Новая 5 (Октябрьский)']
# Количество ЖК без Total: 3, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Мытищи Сити']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 564 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Стоун Сокольники', 'Стоун Райз']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Родники (Раменский район)', 'Олива']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Диус']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 578 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Новая Щербинка']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 582 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Зеленоград Ривьера']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 586 с 'Total'
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Андреевка Лайф']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 588 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Подлипки Город', 'Донской (Коломна)']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Легенда Коренево']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 597 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Шелепиха', 'Вилл Тауэрс', 'Интеллигент', 'Инноватор']
# Количество ЖК без Total: 4, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Триумф']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 608 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Сезар Сити', 'Фулл Хаус']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Новая Москва
# Список ЖК (включая Total): ['Total', 'Рассказово']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 615 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Архитектурный пригород Южная долина', 'Ново-Молоково']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Тетрис', 'М5', 'Базаева 11 (Шаховская)']
# Количество ЖК без Total: 3, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Аист Резиденс']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 630 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Северный порт Береговые кварталы']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 634 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Примавера']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 638 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Стеллар Сити', 'Легаси']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Одинцово Сити']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 647 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Идеал']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 651 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Ю Ту']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 655 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Восток-2']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 659 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Десятка', 'Северный квартал']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Хайд Аут', 'Хайд', 'Свет']
# Количество ЖК без Total: 3, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Аметист']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 674 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Оптима']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 678 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Ривер Парк']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 682 с 'Total'
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Катуар']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 684 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Времена года (Апрелевка)']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 688 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Союзный', 'Одинцовские кварталы']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Селф']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 697 с 'Total'
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Отлично']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 699 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Фестиваль Парк 2']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 703 с 'Total'
#
# Регион: Новая Москва
# Список ЖК (включая Total): ['Total', 'Городские истории']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 705 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Прайм Парк']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 709 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Литейный (Подольск)']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 713 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Квартал Светлый']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 717 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Первый Нагатинский']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 721 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Среда на Лобачевского', 'Среда на Кутузовском']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Проспект 39', 'Дом Франка']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Инсайдер']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 735 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Портал']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 739 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Киноквартал']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 743 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Большевик (Дмитров)', 'Центральный (Ступино)', 'Краснофлотская 9 (Красноармейск)']
# Количество ЖК без Total: 3, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Угрешская 1 (Дзержинский)']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 753 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Садовая 14 (Подольск)']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 757 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Станиславский']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 761 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Бестселлер']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 765 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Кратовоград', 'Южная 7 (Павловский Посад)']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Легенда Марусино']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 774 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Элемент']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 778 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Т Отель Мытищи']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 782 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Зеленый Оазис-Город']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 786 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Бархат']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 790 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Дом Дау']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 794 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Арт (Наро-Фоминск)', 'Авиатор (Наро-Фоминск)']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Берег']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 803 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Театральный Джи 3 (Ильинский)']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 807 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Новая Москва
# Список ЖК (включая Total): ['Total', 'Троицкий']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 811 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Малиново', 'Новый Катуар']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Влюберцы Апарт-комплекс']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 820 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Файв']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 824 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Спрингс']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 828 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Новая Москва
# Список ЖК (включая Total): ['Total', 'Внуково Парк']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 832 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Ривер Парк Кутузовский']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 836 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Куркино 15']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 840 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Сторис', 'Кинг энд Санс']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Мечта']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 849 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Пироговская Ривьера']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 853 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# ...
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Академика Королева 13', 'Оро']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Эхэд']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1133 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Сигма Силино']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1137 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Мессиер 18']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1141 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Вишневый сад']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1145 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Малые Вешки']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1149 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Скай Вью']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1153 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Старт']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1157 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Новая Москва
# Список ЖК (включая Total): ['Total', 'Эдельвейс (Рогозинино)']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1161 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Резиденция 15']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1165 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Садовническая 69']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1169 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Атлантис']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1173 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Вэллби']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1177 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Рабочий 8 (Электросталь)']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1181 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Светлый мир БиоПолиc']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1185 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Белый город']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1189 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Александрия Таун']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1193 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Солнечный (Луховицы)']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1197 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Сенатор']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1201 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Школьный (Наро-Фоминск)']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1205 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Монодом Лейк']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1209 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Новое Сватково']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1213 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Замитино']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1217 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Картье Дор']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1221 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Мой город (Электрогорск)']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1225 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Новое Лыткарино']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1229 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Бородино']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1233 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Новый город Ступино']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1237 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Лесная (Большевик)']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1241 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Культ']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1245 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Империум']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1249 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Брюсов', 'Армани Каза']
# Количество ЖК без Total: 2, Total: 1
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Две Столицы']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1258 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Лесная поляна']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1262 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Кузнецкий мост 12']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1266 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Никитский 6']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1270 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Федоскинская слобода']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1274 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'А22']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1278 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Ивантеевка 2020']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1282 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Тургенев']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1286 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Аннабель']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1290 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Деко Резиденс']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1294 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Камергер']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1298 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Новая Москва
# Список ЖК (включая Total): ['Total', 'Внуково Кантри Клаб']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1302 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Время']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1306 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Центральный (Одинцово)']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1310 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Ленинский 38']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1314 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Московская область
# Список ЖК (включая Total): ['Total', 'Три квартала']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1318 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Total
# Список ЖК (включая Total): ['None']
# Количество ЖК без Total: 1, Total: 0
#
# Регион: Москва
# Список ЖК (включая Total): ['Total', 'Соле Хиллс']
# Количество ЖК без Total: 1, Total: 1
# Удаляю строку 1322 с 'Total'
#
# Регион: Регион
# Список ЖК (включая Total): ['Название ЖК']
# Количество ЖК без Total: 1, Total: 0
# ✅ Готово! Шапки добавлены, выделены цветом, и ячейки объединены.
