# %%
import pandas as pd
from openpyxl import load_workbook
from openpyxl.styles import Font, PatternFill, Alignment
from openpyxl.utils import get_column_letter
import datetime
import locale
locale.setlocale(locale.LC_TIME, 'ru_RU.UTF-8')
from io import BytesIO

# %%
# Словарь месяцев вручную, чтобы избежать проблем с кодировкой
months_ru = {
    1: "янв", 2: "фев", 3: "мар", 4: "апр", 5: "май", 6: "июн",
    7: "июл", 8: "авг", 9: "сен", 10: "окт", 11: "ноя", 12: "дек"
}

# %%
df = pd.read_excel(r"C:\Users\m.olshanskiy\Desktop\122025_Продажи за ноябрь (1).xlsx", sheet_name='рейтинг')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Рейтинг     236 non-null    int64
#  1   Застройщик  236 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 3.8+ KB

# %%
df
# Out:
#      Рейтинг         Застройщик
# 0          1                ПИК
# 1          2            Самолет
# 2          3               А101
# 3          4                ЛСР
# 4          5  ДСК-1 (ФСК Лидер)
# ..       ...                ...
# 231      232            Бэсткон
# 232      233  Инвестстройрегион
# 233      234           Меджиком
# 234      235                ПСТ
# 235      236  СК Олимпийский 10
#
# [236 rows x 2 columns]

# %%
developers = df["Застройщик"].tolist()

# %%
df2 = pd.read_excel(r"C:\Users\m.olshanskiy\Desktop\122025_Продажи за ноябрь (1).xlsx", sheet_name='массив')

# %%
def format_col(col):
    if isinstance(col, (pd.Timestamp, datetime.datetime)):
        return f"{months_ru[col.month]}.{str(col.year)[-2:]}"
    return col

df2.columns = [format_col(col) for col in df2.columns]

# %%
# Фильтруем по каждому региону
def remove_total_if_one_jk(group):
    # Проверяем сколько строк с ЖК (не Total)
    jk_count = group[group["Название ЖК"] != "Total"].shape[0]
    if jk_count <= 1:
        # Удаляем строки с Total
        group = group[group["Название ЖК"] != "Total"]
    return group

# %%
# Проверяем результат
print(df2.columns.tolist())
# Out:
# ['Застройщик', 'Регион', 'Название ЖК', 'Среднее за 2024 г., шт', 'янв.25', 'фев.25', 'мар.25', 'апр.25', 'май.25', 'июн.25', 'июл.25', 'авг.25', 'сен.25', 'окт.25', 'ноя.25', 'Среднее за 2025 г., шт']

# %%
region_order = ['Total', 'Москва', 'Новая Москва', 'Московская область']

# %%
# 2. Создаём словарь: застройщик → порядковый номер
developer_numbers = {name: i + 1 for i, name in enumerate(df["Застройщик"].dropna().unique())}

# 3. Добавляем новый столбец с номерами
df2["№"] = df2["Застройщик"].map(developer_numbers)

# 4. Ставим столбец "№" в начало
df2 = df2[["№"] + [col for col in df2.columns if col != "№"]]

# %%
df2['Застройщик'] = pd.Categorical(df2['Застройщик'], categories=developers, ordered=True)
df2['Регион'] = pd.Categorical(df2['Регион'], categories=region_order, ordered=True)
df_sorted = df2.sort_values(['Застройщик', 'Регион']).reset_index(drop=True)

# 5. Дублируем шапку перед каждым застройщиком
header = pd.DataFrame([df_sorted.columns], columns=df_sorted.columns)  # создаём строку-шапку
result = pd.DataFrame(columns=df_sorted.columns)

for dev in df_sorted["№"].unique():
    block = df_sorted[df_sorted["№"] == dev]
    result = pd.concat([result, header, block], ignore_index=True)

df_sorted = result

# 5. Заменяем все значения "Total" на "Итого"
# df_sorted = df_sorted.replace("Total", "Итого")

df_sorted = df_sorted.groupby("Регион", group_keys=False).apply(remove_total_if_one_jk)
# Out:
# C:\Users\m.olshanskiy\AppData\Local\Temp\ipykernel_5340\3313678032.py:18: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_sorted = df_sorted.groupby("Регион", group_keys=False).apply(remove_total_if_one_jk)

# %%
df_sorted = df_cleaned

# %%
# --- 2. Сохраняем в Excel ---
output_file = r"C:\Users\m.olshanskiy\Desktop\Продажи отсортированные 08.12-3.xlsx"
df_sorted.to_excel(output_file, index=False)

# --- 3. Открываем для форматирования ---
wb = load_workbook(output_file)
ws = wb.active

# Проверяем, сколько регионов в файле (не считая общего Итого)
all_regions = [
    str(ws[f"C{row}"].value).strip()
    for row in range(2, ws.max_row + 1)
    if ws[f"C{row}"].value not in [None, "", "Итого"]
]

unique_regions = set(all_regions)
single_region_in_file = len(unique_regions) == 1
print("В файле один регион?", single_region_in_file)

region_start = None
region_end = None
current_region = None
rows_to_delete = []

for row in range(2, ws.max_row + 1):  # первая строка — заголовок
    region = ws[f"C{row}"].value  # регион
    jk_name = ws[f"D{row}"].value  # ЖК / Total

    if region is None:
        continue
    if jk_name is None:
        jk_name = ""

    if region != current_region:
        if region_start is not None:

            # Список ЖК в регионе
            jk_list = [
                str(ws[f"D{r}"].value).strip()
                for r in range(region_start, region_end + 1)
            ]
            total_count = sum(1 for name in jk_list if name.lower() == "total")
            real_jk_count = sum(1 for name in jk_list if name.lower() != "total")

            print(f"\nРегион: {current_region}")
            print(f"ЖК: {jk_list}")
            print(f"real={real_jk_count}, total={total_count}")

            # === УСЛОВИЕ №2: если во всём файле один регион → удаляем все Total ===
            if single_region_in_file:
                for r in range(region_start, region_end + 1):
                    if str(ws[f"D{r}"].value).strip().lower() == "total":
                        rows_to_delete.append(r)
                        print(f"Удаляю строку {r} (Total — единственный регион)")
                # Переходим к следующему региону
                current_region = region
                region_start = row
                continue

            # === УСЛОВИЕ №1: если ЖК внутри региона только один → удаляем Total ===
            if real_jk_count == 1 and total_count > 0:
                for r in range(region_start, region_end + 1):
                    if str(ws[f"D{r}"].value).strip().lower() == "total":
                        rows_to_delete.append(r)
                        print(f"Удаляю строку {r} (Total — один ЖК в регионе)")

        current_region = region
        region_start = row

    region_end = row

# Проверка последнего региона — аналогичная логика
jk_list = [
    str(ws[f"D{r}"].value).strip()
    for r in range(region_start, region_end + 1)
]
total_count = sum(1 for name in jk_list if name.lower() == "total")
real_jk_count = sum(1 for name in jk_list if name.lower() != "total")

if single_region_in_file:
    for r in range(region_start, region_end + 1):
        if str(ws[f"D{r}"].value).strip().lower() == "total":
            rows_to_delete.append(r)
else:
    if real_jk_count == 1 and total_count > 0:
        for r in range(region_start, region_end + 1):
            if str(ws[f"D{r}"].value).strip().lower() == "total":
                rows_to_delete.append(r)

# Удаляем строки с конца
for r in sorted(rows_to_delete, reverse=True):
    ws.delete_rows(r)

# Эта часть добавляет шапку для каждого застройщика, а также добавляет серую заливку и жирный шрифт

# Форматы
fill = PatternFill(start_color="D9D9D9", end_color="D9D9D9", fill_type="solid")
bold_font = Font(bold=True)
center_align = Alignment(vertical="center", horizontal="center")

# --- 4. Форматируем строки-шапки ---
for row in ws.iter_rows(min_row=1, max_row=ws.max_row):
    if row[0].value == "№":  # шапка начинается со "№"
        for cell in row:
            cell.font = bold_font
            cell.fill = fill
            cell.alignment = center_align

# --- 5. Объединяем одинаковые подряд ячейки ---
def merge_identical_cells(column_idx):
    start = 2  # пропускаем первую строку
    current_value = ws[f"{get_column_letter(column_idx)}{start}"].value
    for row in range(3, ws.max_row + 2):
        cell_value = ws[f"{get_column_letter(column_idx)}{row}"].value
        if cell_value != current_value:
            if row - start > 1 and current_value is not None:
                ws.merge_cells(start_row=start, start_column=column_idx,
                               end_row=row - 1, end_column=column_idx)
                ws[f"{get_column_letter(column_idx)}{start}"].alignment = center_align
            start = row
            current_value = cell_value

# Объединяем по нужным столбцам
merge_identical_cells(1)  # №
merge_identical_cells(2)  # Застройщик
merge_identical_cells(3)  # Регион
merge_identical_cells(4)  # Название ЖК (если нужно)




# --- 6. Сохраняем итог ---
wb.save(output_file)
print("✅ Готово! Шапки добавлены, выделены цветом, и ячейки объединены.")
# Out:
# В файле один регион? False
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Бусиновский парк', 'Люблинский парк', 'Москворечье', 'Зеленый парк', 'Матвеевский парк', 'Плеханова 11', 'Большая Академическая 85', 'Алтуфьевское 53', 'Холланд Парк', 'Волжский парк', 'Кавказский 51', 'Никольские луга', 'Мичуринский парк', 'Второй Иртышский', 'Руставели 14', 'Амурский Парк', 'Полар', 'Второй Нагатинский', 'Первый Дубровский', 'Митинский лес', 'Барклая 6', 'Сигнальный 16', 'Ютаново', 'Кутузовский квартал', 'Новое Очаково', 'Кольская 8', 'Кронштадтский 9', 'Римского-Корсакова 11', 'Полярная 25', 'Квартал Мит', 'Открытый парк', 'Нарвин', 'Большая Очаковская 2', 'Кронштадтский 14', 'Лосиноостровский парк', 'Онежский вал', 'Красноказарменная 15', 'Перовское 2', 'Вангарден']
# real=39, total=1
#
# Регион: Новая Москва
# ЖК: ['Total', 'Саларьево Парк', 'Середневский лес', 'Юнино', 'Бунинские луга', 'Бунинская набережная']
# real=5, total=1
#
# Регион: Московская область
# ЖК: ['Total', 'Ильинские луга', 'Яуза Парк (Мытищи)', 'Ярославский квартал', 'Восточное Бутово', 'Белая Дача Парк', 'Ярославский', 'Одинцово-1', 'Томилинский бульвар', 'Кузьминский лес', 'Измайловский леc', 'Жулебино Парк']
# real=11, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Молжаниново', 'Квартал Домашний', 'Верейская 41', 'Октябрьская 98', 'Квартал на воде', 'Нова', 'Стремянный 2']
# real=7, total=1
#
# Регион: Новая Москва
# ЖК: ['Total', 'Остафьево', 'Эко Бунино', 'Новое Внуково', 'Квартал Западный', 'Цветочные поляны Экопарк', 'Квартал Марьино', 'Подольские кварталы', 'Тропарево Парк', 'Цветочные поляны Сити', 'Алхимово', 'Квартал Румянцево', 'Ольховый квартал']
# real=12, total=1
#
# Регион: Московская область
# ЖК: ['Total', 'Пригород Лесное', 'Мытищи Парк', 'Новоград Павлино', 'Горки Парк', 'Новое Видное', 'Прибрежный парк', 'Рублевский квартал', 'Пятницкие луга', 'Квартал Ивакино', 'Егорово Парк', 'Томилино Парк', 'Богдановский Лес', 'Квартал Строгино', 'Квартал Авиаторов', 'Большое Путилково', 'Скай Спутник', 'Долина Яузы', 'Космический квартал', 'Люберцы 2018-2023', 'Заречье Парк']
# real=20, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Южные сады', 'Дом на Зорге']
# real=2, total=1
#
# Регион: Новая Москва
# ЖК: ['Total', 'Бунинские кварталы', 'Прокшино', 'Дзен-Кварталы', 'Скандинавия Центр', 'Деснаречье', 'Скандинавия Юг', 'Родные кварталы']
# real=7, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Лучи-2', 'Зиларт', 'Вэйв', 'Дмитровское небо', 'Парк Сайд', 'Обручева 30', 'Марк', 'Ле Дом']
# real=8, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Первый Измайловский', 'Первый Ленинградский']
# real=2, total=1
#
# Регион: Новая Москва
# ЖК: ['Total', 'Первый Ясеневский', 'Первый Саларьевский']
# real=2, total=1
#
# Регион: Московская область
# ЖК: ['Total', 'Первый Южный', 'Первый Шереметьевский', 'Первый Донской', 'Первый Химкинский', 'Южная Битца', 'Первый Лермонтовский']
# real=6, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Би Лак', 'Май Приорити Басманный', 'Тринити-3', 'Май Приорити Дубровка', 'Май Приорити Павелецкая', 'Хайвэй', 'Май Приорити Нижегородская', 'Май Приорити Мневники', 'Тринити']
# real=9, total=1
#
# Регион: Московская область
# ЖК: ['Total', 'Ильинойс', 'Аникеевский', 'Бригантина (Долгопрудный)', 'Новая Рига', 'Пехра', 'Новая Алексеевская роща', 'Театральный парк', 'Живописный']
# real=8, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Квартал Метроном', 'Квартал Герцена', 'Издание', 'Монс', 'Дом А']
# real=5, total=1
#
# Регион: Московская область
# ЖК: ['Total', 'Первый квартал']
# real=1, total=1
# Удаляю строку 174 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Сити Бэй', 'Ситизен', 'Сет', 'Джойс', 'Мод', 'Веер', 'Селигер Сити', 'Павелецкая Сити', 'Слава', 'Симфони 34', 'Метрополия', 'Мира', 'Фили Сити', 'Николь', 'Уан Тауэр', 'Форум', 'Луче', 'Климашкина 7/11', 'Клос 17']
# real=19, total=1
#
# Регион: Московская область
# ЖК: ['Total', 'Эко Видное 2.0', 'Мыс']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Сидней Сити', 'Скай Гарден', 'Амбер Сити', 'Роттердам', 'Архитектор', 'Лэйк', 'Режиссер']
# real=7, total=1
#
# Регион: Новая Москва
# ЖК: ['Total', 'Движение Говорово']
# real=1, total=1
# Удаляю строку 211 (Total — один ЖК в регионе)
#
# Регион: Московская область
# ЖК: ['Total', 'Апрелевка Клаб', 'Римский', 'Жаворонки Клаб']
# real=3, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Публицист', 'Эво']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Акценты']
# real=1, total=1
# Удаляю строку 224 (Total — один ЖК в регионе)
#
# Регион: Новая Москва
# ЖК: ['Total', 'Детали']
# real=1, total=1
# Удаляю строку 226 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Остров', 'Символ', 'Событие', 'Большая Татарская 35', 'Река', 'Дом 22', 'Огни']
# real=7, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Баланс', 'Береговой', 'Новые Академики']
# real=3, total=1
#
# Регион: Московская область
# ЖК: ['Total', 'Квартал героев', 'Столичный']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Лайф Тайм', 'Тишинский бульвар', 'Достижение', 'Форивер', 'Фрунзенская набережная', 'Лаврушинский', 'Чистые пруды', 'Ильинка 3/8', 'Обыденский 1', 'Форивер Резиденс']
# real=10, total=1
#
# Регион: Новая Москва
# ЖК: ['Total', 'Филатов луг']
# real=1, total=1
# Удаляю строку 260 (Total — один ЖК в регионе)
#
# Регион: Московская область
# ЖК: ['Total', 'Белый Град', 'Новое Пушкино', 'Новое Медведково', 'Одинград Семейный квартал', 'Миловидное']
# real=5, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Левел Южнопортовая', 'Левел Мичуринский', 'Левел Нижегородская', 'Левел Звенигородская', 'Левел Селигерская', 'Левел Бауманская', 'Левел Академическая', 'Левел Причальный', 'Левел Войковская', 'Левел Нагатинская', 'Левел Стрешнево', 'Саввинская 27', 'Саввинская 17']
# real=13, total=1
#
# Регион: Московская область
# ЖК: ['Total', 'Левел Лесной']
# real=1, total=1
# Удаляю строку 284 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Эра', 'Твелв 12', 'Эвер', 'Ками']
# real=4, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Никольский квартал Отрада', 'Смарт Квартал Лесная отрада', 'Отрада на реке', 'Отрада Сити Квартал', 'Отрада Комфорт']
# real=5, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Мираполис', 'Наметкин Тауэр', 'Вэри', 'Эво Парк Сокольники', 'Уно Соколиная гора', 'Эмоушн', 'Эво Парк Измайлово', 'Уно Головинские пруды', 'Физтех Сити', 'Уно Горбунова', 'Ред 7']
# real=11, total=1
#
# Регион: Московская область
# ЖК: ['Total', 'Гоголь Парк']
# real=1, total=1
# Удаляю строку 315 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Страна Озерная', 'Репаблик', 'Страна Заречная', 'Вау']
# real=4, total=1
#
# Регион: Московская область
# ЖК: ['Total', 'Страна Парковая']
# real=1, total=1
# Удаляю строку 324 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Шагал', 'Воксхолл', 'Мариин Парк', 'СоколИнн']
# real=4, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Новая Москва
# ЖК: ['Total', 'Новые Ватутинки Заречный', 'Новые Ватутинки', 'Новое Летово']
# real=3, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Коллекция Лужники']
# real=1, total=1
# Удаляю строку 341 (Total — один ЖК в регионе)
#
# Регион: Новая Москва
# ЖК: ['Total', 'Переделкино Ближнее', 'Первый Московский']
# real=2, total=1
#
# Регион: Московская область
# ЖК: ['Total', 'Резиденции Сколково']
# real=1, total=1
# Удаляю строку 346 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Фабрикант', 'Западная Ивантеевка', 'Ривер Парк (Королев)', 'Новая Ивантеевка', 'Седьмое небо', '31-й квартал (Пушкино)', 'Дом на Студенческой', 'Поколение первых', 'Тургенева 9-13 (Пушкино)']
# real=9, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Аквилон Сигнал', 'Аквилон Бисайд', 'Инди Тауэрс', 'Аквилон Митино']
# real=4, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Дюна (Котельники)', 'Дюна Сити']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Михалковский', 'Варшавские ворота', 'Семеновский парк 2', 'Петровский парк 2', 'Родной Город. Октябрьское поле']
# real=5, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Соул', 'Моментс', 'Портлэнд', 'Паве', 'Форст']
# real=5, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Айс Туэрс']
# real=1, total=1
# Удаляю строку 390 (Total — один ЖК в регионе)
#
# Регион: Московская область
# ЖК: ['Total', 'Домодедово Парк Новый квартал', 'Химки Тайм', 'Лесная коллекция']
# real=3, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Первый Нагатинский']
# real=1, total=1
# Удаляю строку 398 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Сиреневый парк', 'Афи Тауэр', 'Афи Парк Воронцовский']
# real=3, total=1
#
# Регион: Московская область
# ЖК: ['Total', 'Одинбург']
# real=1, total=1
# Удаляю строку 406 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Войс Тауэрс']
# real=1, total=1
# Удаляю строку 410 (Total — один ЖК в регионе)
#
# Регион: Новая Москва
# ЖК: ['Total', 'Форвиль']
# real=1, total=1
# Удаляю строку 412 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Тэйт', 'Ультима Сити', 'Ай Лав', 'Хэдлайнер']
# real=4, total=1
#
# Регион: Московская область
# ЖК: ['Total', 'Равновесие']
# real=1, total=1
# Удаляю строку 421 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Среда на Лобачевского', 'Среда на Кутузовском']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Малевич', 'Кристал', 'Театральный квартал', 'Высотка на Жукова']
# real=4, total=1
#
# Регион: Новая Москва
# ЖК: ['Total', 'Новая Звезда']
# real=1, total=1
# Удаляю строку 435 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Новая Москва
# ЖК: ['Total', 'Новые смыслы']
# real=1, total=1
# Удаляю строку 439 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Союз', 'Родина Парк', 'Родина Переделкино']
# real=3, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Хай Лайф', 'Лайф Варшавская', 'Прайд', 'Шифт', 'Опус']
# real=5, total=1
#
# Регион: Московская область
# ЖК: ['Total', 'Рублево Бизнес Парк (офисы)']
# real=1, total=1
# Удаляю строку 455 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Русич Кантемировский']
# real=1, total=1
# Удаляю строку 459 (Total — один ЖК в регионе)
#
# Регион: Московская область
# ЖК: ['Total', 'Новые Котельники']
# real=1, total=1
# Удаляю строку 461 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Зеленоград Ривьера']
# real=1, total=1
# Удаляю строку 465 (Total — один ЖК в регионе)
#
# Регион: Московская область
# ЖК: ['Total', 'Андреевка Лайф']
# real=1, total=1
# Удаляю строку 467 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Новая Москва
# ЖК: ['Total', 'Смарт Гарден']
# real=1, total=1
# Удаляю строку 471 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Пушкиноград']
# real=1, total=1
# Удаляю строку 475 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Апсайд Тауэрс', 'Клементин']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Каштановая роща']
# real=1, total=1
# Удаляю строку 484 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Рига Хиллс']
# real=1, total=1
# Удаляю строку 488 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Тетрис', 'М5', 'Базаева 11 (Шаховская)']
# real=3, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Грин Гарден']
# real=1, total=1
# Удаляю строку 498 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Инджой']
# real=1, total=1
# Удаляю строку 502 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Т Отель Мытищи']
# real=1, total=1
# Удаляю строку 506 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Дрим Рива', 'Преображенская площадь']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Московский (Подольск)']
# real=1, total=1
# Удаляю строку 515 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Мангазея на Речном', 'НаЗаре', 'Мангазея на Тульской', 'Интонация']
# real=4, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Алиа']
# real=1, total=1
# Удаляю строку 526 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Дом 56 на Энгельса', 'Адмирал', 'Монблан', 'Космо 4/22', 'Рождественка 8']
# real=5, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Селигерская 32А (реновация)', 'Профсоюзная 60 (реновация)', 'Люблинская 52/1 (реновация)', 'Полярная 4 (реновация)', 'Кусковская 12 (реновация)']
# real=5, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Феникс', 'Ценности']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Чкалов']
# real=1, total=1
# Удаляю строку 551 (Total — один ЖК в регионе)
#
# Регион: Московская область
# ЖК: ['Total', 'Новый Зеленоград', 'Сколково Уан']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Аист Резиденс']
# real=1, total=1
# Удаляю строку 558 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Отрадный']
# real=1, total=1
# Удаляю строку 562 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Ракурс', 'Солос']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Новотомилино', 'Видный берег 2', 'Облака 2.0']
# real=3, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Легенда Марусино']
# real=1, total=1
# Удаляю строку 577 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Стоун Сокольники', 'Стоун Райз']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Северный порт Береговые кварталы']
# real=1, total=1
# Удаляю строку 586 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Планерный квартал']
# real=1, total=1
# Удаляю строку 590 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Легенда Коренево']
# real=1, total=1
# Удаляю строку 594 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Кит']
# real=1, total=1
# Удаляю строку 598 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Волковская 67 (Люберцы)', 'Дом в Малаховке', 'Новая 5 (Октябрьский)']
# real=3, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Шелепиха', 'Интеллигент', 'Вилл Тауэрс', 'Инноватор']
# real=4, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Сити Микc', 'Сити Микс Новокосино']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Родники (Раменский район)', 'Олива']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Новая Щербинка']
# real=1, total=1
# Удаляю строку 625 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Десятка', 'Северный квартал']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Одинцово Сити']
# real=1, total=1
# Удаляю строку 634 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Шолохово', 'Южное Пушкино']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Примавера']
# real=1, total=1
# Удаляю строку 643 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Идеал']
# real=1, total=1
# Удаляю строку 647 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Квартал Светлый']
# real=1, total=1
# Удаляю строку 651 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Одинцовские кварталы Эволюция']
# real=1, total=1
# Удаляю строку 655 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Архитектурный пригород Южная долина', 'Ново-Молоково']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Ю Ту']
# real=1, total=1
# Удаляю строку 664 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Московский (Сергиев Посад)']
# real=1, total=1
# Удаляю строку 668 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Стеллар Сити', 'Легаси']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Триумф']
# real=1, total=1
# Удаляю строку 677 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Сберсити']
# real=1, total=1
# Удаляю строку 681 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Сезар Сити', 'Фулл Хаус']
# real=2, total=1
#
# Регион: Новая Москва
# ЖК: ['Total', 'Рассказово']
# real=1, total=1
# Удаляю строку 688 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Союзный', 'Одинцовские кварталы']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Фестиваль Парк 2']
# real=1, total=1
# Удаляю строку 697 (Total — один ЖК в регионе)
#
# Регион: Новая Москва
# ЖК: ['Total', 'Городские истории']
# real=1, total=1
# Удаляю строку 699 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Оптима']
# real=1, total=1
# Удаляю строку 703 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Мытищи Сити']
# real=1, total=1
# Удаляю строку 707 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Инсайдер']
# real=1, total=1
# Удаляю строку 711 (Total — один ЖК в регионе)
#
# Регион: Московская область
# ЖК: ['Total', 'Коллекция']
# real=1, total=1
# Удаляю строку 713 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Аметист']
# real=1, total=1
# Удаляю строку 717 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Восточный (Звенигород)', 'Школьный (Подольск)', 'Садовая 14 (Подольск)']
# real=3, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Хайд Аут', 'Свет', 'Хайд']
# real=3, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Угрешская 1 (Дзержинский)']
# real=1, total=1
# Удаляю строку 733 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Пироговская Ривьера']
# real=1, total=1
# Удаляю строку 737 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Ривер Парк']
# real=1, total=1
# Удаляю строку 741 (Total — один ЖК в регионе)
#
# Регион: Московская область
# ЖК: ['Total', 'Катуар']
# real=1, total=1
# Удаляю строку 743 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Проспект 39', 'Дом Франка']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Квартал Серебряный бор']
# real=1, total=1
# Удаляю строку 752 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Киноквартал']
# real=1, total=1
# Удаляю строку 756 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Времена года (Апрелевка)']
# real=1, total=1
# Удаляю строку 760 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Берег']
# real=1, total=1
# Удаляю строку 764 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Ривер Парк Кутузовский']
# real=1, total=1
# Удаляю строку 768 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Подлипки Город', 'Донской (Коломна)']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Поварово Молодежный 2', 'Молодежный (Солнечногорск)']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Селф']
# real=1, total=1
# Удаляю строку 782 (Total — один ЖК в регионе)
#
# Регион: Московская область
# ЖК: ['Total', 'Отлично']
# real=1, total=1
# Удаляю строку 784 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Станиславский']
# real=1, total=1
# Удаляю строку 788 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Новая Москва
# ЖК: ['Total', 'Внуково Парк']
# real=1, total=1
# Удаляю строку 792 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Литейный (Подольск)']
# real=1, total=1
# Удаляю строку 796 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Бестселлер']
# real=1, total=1
# Удаляю строку 800 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Новая Москва
# ЖК: ['Total', 'Троицкий']
# real=1, total=1
# Удаляю строку 804 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Кашинцево']
# real=1, total=1
# Удаляю строку 808 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Зеленый Оазис-Город']
# real=1, total=1
# Удаляю строку 812 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Дмитровка 9']
# real=1, total=1
# Удаляю строку 816 (Total — один ЖК в регионе)
#
# Регион: Московская область
# ЖК: ['Total', 'Мишино']
# real=1, total=1
# Удаляю строку 818 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Куркино 15']
# real=1, total=1
# Удаляю строку 822 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Кратовоград', 'Южная 7 (Павловский Посад)']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Аллегория Моска']
# real=1, total=1
# Удаляю строку 831 (Total — один ЖК в регионе)
#
# Регион: Московская область
# ЖК: ['Total', 'Цветочный город']
# real=1, total=1
# Удаляю строку 833 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Восток-2']
# real=1, total=1
# Удаляю строку 837 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Влюберцы Апарт-комплекс']
# real=1, total=1
# Удаляю строку 841 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Театральный Джи 3 (Ильинский)']
# real=1, total=1
# Удаляю строку 845 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Большевик (Дмитров)', 'Центральный (Ступино)', 'Краснофлотская 9 (Красноармейск)']
# real=3, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Элемент']
# real=1, total=1
# Удаляю строку 855 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Сити Строгино']
# real=1, total=1
# Удаляю строку 859 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Прайм Парк']
# real=1, total=1
# Удаляю строку 863 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Сторис', 'Кинг энд Санс']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Малиново', 'Новый Катуар']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Портал']
# real=1, total=1
# Удаляю строку 877 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Бархат']
# real=1, total=1
# Удаляю строку 881 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Павлово-3']
# real=1, total=1
# Удаляю строку 885 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Первый Рязанский']
# real=1, total=1
# Удаляю строку 889 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Новоград Монино']
# real=1, total=1
# Удаляю строку 893 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Клевер', 'Майданово Парк']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Ом']
# real=1, total=1
# Удаляю строку 902 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Крылатская 33']
# real=1, total=1
# Удаляю строку 906 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Новая Москва
# ЖК: ['Total', 'Внуково Кантри Клаб']
# real=1, total=1
# Удаляю строку 910 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Найс Лофт', 'Дом 7 Даниловский', 'Хамовники 12']
# real=3, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Фрунзенский']
# real=1, total=1
# Удаляю строку 920 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Юго-Западный (Ступино)']
# real=1, total=1
# Удаляю строку 924 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Бадаевский']
# real=1, total=1
# Удаляю строку 928 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Мечта']
# real=1, total=1
# Удаляю строку 932 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Квартал 24 (Дубна)']
# real=1, total=1
# Удаляю строку 936 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Спрингс']
# real=1, total=1
# Удаляю строку 940 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Диус']
# real=1, total=1
# Удаляю строку 944 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Мессиер 18']
# real=1, total=1
# Удаляю строку 948 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Горки Марусино']
# real=1, total=1
# Удаляю строку 952 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Кутузов Сити']
# real=1, total=1
# Удаляю строку 956 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Парк Апрель', 'Мартемьяново Клаб']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Арт (Наро-Фоминск)', 'Авиатор (Наро-Фоминск)']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Файв']
# real=1, total=1
# Удаляю строку 970 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Сантерра']
# real=1, total=1
# Удаляю строку 974 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Вишневый сад']
# real=1, total=1
# Удаляю строку 978 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Ивановские дворики']
# real=1, total=1
# Удаляю строку 982 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Новое Вашутино', 'Лобня Сити']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Доро Милле']
# real=1, total=1
# Удаляю строку 991 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Солнечный (Луховицы)']
# real=1, total=1
# Удаляю строку 995 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Коммунистическая 40 (Озеры)']
# real=1, total=1
# Удаляю строку 999 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Дом Дау']
# real=1, total=1
# Удаляю строку 1003 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Троицкая слобода']
# real=1, total=1
# Удаляю строку 1007 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Логос', 'Фантом']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Веспер Кутузовский', 'Левенсон']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Садовническая 69']
# real=1, total=1
# Удаляю строку 1021 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Лесной (Егорьевск)']
# real=1, total=1
# Удаляю строку 1025 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Бруно']
# real=1, total=1
# Удаляю строку 1029 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Федоскинская слобода']
# real=1, total=1
# Удаляю строку 1033 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'А22']
# real=1, total=1
# Удаляю строку 1037 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Нагатино Ай Лэнд']
# real=1, total=1
# Удаляю строку 1041 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Космос (Домодедово)']
# real=1, total=1
# Удаляю строку 1045 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Высокие жаворонки']
# real=1, total=1
# Удаляю строку 1049 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Либерти']
# real=1, total=1
# Удаляю строку 1053 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Шоколад (Дмитров)']
# real=1, total=1
# Удаляю строку 1057 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Соболевка Парк']
# real=1, total=1
# Удаляю строку 1061 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Самоцветы мира']
# real=1, total=1
# Удаляю строку 1065 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Новая Москва
# ЖК: ['Total', 'Академик (Троицк)']
# real=1, total=1
# Удаляю строку 1069 (Total — один ЖК в регионе)
#
# Регион: Московская область
# ЖК: ['Total', 'Благодар']
# real=1, total=1
# Удаляю строку 1071 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Радость']
# real=1, total=1
# Удаляю строку 1075 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Дом-Мегалит в Королеве']
# real=1, total=1
# Удаляю строку 1079 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Гармония Парк']
# real=1, total=1
# Удаляю строку 1083 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Квартал С-3 (Дубна)']
# real=1, total=1
# Удаляю строку 1087 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Восемь кленов']
# real=1, total=1
# Удаляю строку 1091 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Шампайн', 'Дом горизонтов']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Измайловский парк']
# real=1, total=1
# Удаляю строку 1100 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Ступино Сити']
# real=1, total=1
# Удаляю строку 1104 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Виктори Парк Резиденс']
# real=1, total=1
# Удаляю строку 1108 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Глоракс Премиум Белорусская']
# real=1, total=1
# Удаляю строку 1112 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Артель']
# real=1, total=1
# Удаляю строку 1116 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Кинетик']
# real=1, total=1
# Удаляю строку 1120 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Радужный (Кашира)']
# real=1, total=1
# Удаляю строку 1124 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Большая Семерка']
# real=1, total=1
# Удаляю строку 1128 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Высокий берег (Лыткарино)']
# real=1, total=1
# Удаляю строку 1132 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Солнечная долина', 'Дом на Сиреневой']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Лунар', 'Клубный дом Дуо']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Олимп-2 (Хотьково)']
# real=1, total=1
# Удаляю строку 1146 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Академика Королева 13', 'Оро']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Эхэд']
# real=1, total=1
# Удаляю строку 1155 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Сигма Силино']
# real=1, total=1
# Удаляю строку 1159 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Малые Вешки']
# real=1, total=1
# Удаляю строку 1163 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Скай Вью']
# real=1, total=1
# Удаляю строку 1167 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Старт']
# real=1, total=1
# Удаляю строку 1171 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Новая Москва
# ЖК: ['Total', 'Эдельвейс (Рогозинино)']
# real=1, total=1
# Удаляю строку 1175 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Резиденция 15']
# real=1, total=1
# Удаляю строку 1179 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Атлантис']
# real=1, total=1
# Удаляю строку 1183 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Вернисаж', 'Зиккурат Преображенский']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Вэллби']
# real=1, total=1
# Удаляю строку 1192 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Рабочий 8 (Электросталь)']
# real=1, total=1
# Удаляю строку 1196 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Светлый мир БиоПолиc']
# real=1, total=1
# Удаляю строку 1200 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Белый город']
# real=1, total=1
# Удаляю строку 1204 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Александрия Таун']
# real=1, total=1
# Удаляю строку 1208 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Сенатор']
# real=1, total=1
# Удаляю строку 1212 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Школьный (Наро-Фоминск)']
# real=1, total=1
# Удаляю строку 1216 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Монодом Лейк']
# real=1, total=1
# Удаляю строку 1220 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Новое Сватково']
# real=1, total=1
# Удаляю строку 1224 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Замитино']
# real=1, total=1
# Удаляю строку 1228 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Картье Дор']
# real=1, total=1
# Удаляю строку 1232 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Мой город (Электрогорск)']
# real=1, total=1
# Удаляю строку 1236 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Новое Лыткарино']
# real=1, total=1
# Удаляю строку 1240 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Русские сезоны']
# real=1, total=1
# Удаляю строку 1244 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Бородино']
# real=1, total=1
# Удаляю строку 1248 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Новый город Ступино']
# real=1, total=1
# Удаляю строку 1252 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Лесная (Большевик)']
# real=1, total=1
# Удаляю строку 1256 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Культ']
# real=1, total=1
# Удаляю строку 1260 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Империум']
# real=1, total=1
# Удаляю строку 1264 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Брюсов', 'Армани Каза']
# real=2, total=1
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Две Столицы']
# real=1, total=1
# Удаляю строку 1273 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Лесная поляна']
# real=1, total=1
# Удаляю строку 1277 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Кузнецкий мост 12']
# real=1, total=1
# Удаляю строку 1281 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Никитский 6']
# real=1, total=1
# Удаляю строку 1285 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Первый на Красном']
# real=1, total=1
# Удаляю строку 1289 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Ивантеевка 2020']
# real=1, total=1
# Удаляю строку 1293 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Вяземы Парк']
# real=1, total=1
# Удаляю строку 1297 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Тургенев']
# real=1, total=1
# Удаляю строку 1301 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Аннабель']
# real=1, total=1
# Удаляю строку 1305 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Деко Резиденс']
# real=1, total=1
# Удаляю строку 1309 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Камергер']
# real=1, total=1
# Удаляю строку 1313 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Время']
# real=1, total=1
# Удаляю строку 1317 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Центральный (Одинцово)']
# real=1, total=1
# Удаляю строку 1321 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Ленинский 38']
# real=1, total=1
# Удаляю строку 1325 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Московская область
# ЖК: ['Total', 'Три квартала']
# real=1, total=1
# Удаляю строку 1329 (Total — один ЖК в регионе)
#
# Регион: Регион
# ЖК: ['Название ЖК']
# real=1, total=0
#
# Регион: Total
# ЖК: ['None']
# real=1, total=0
#
# Регион: Москва
# ЖК: ['Total', 'Соле Хиллс']
# real=1, total=1
# Удаляю строку 1333 (Total — один ЖК в регионе)
# ✅ Готово! Шапки добавлены, выделены цветом, и ячейки объединены.
