# %%
import pandas as pd

# %%
df = pd.read_excel(r"D:\НДВ\Города млн\Май 2026\Млн Первичка Май 2026 с классами.xlsx")

# %%
df['Дата'] =

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244187 entries, 0 to 244186
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Название проекта          244187 non-null  object
#  1   Девелопер                 244187 non-null  object
#  2   Класс                     0 non-null       float64
#  3   Локация                   244187 non-null  object
#  4   Локация2                  227502 non-null  object
#  5   Округ                     81121 non-null   object
#  6   Район                     177793 non-null  object
#  7   Микрорайон                89214 non-null   object
#  8   Метро                     104828 non-null  object
#  9   Улица                     117597 non-null  object
#  10  Дом                       103650 non-null  object
#  11  Корпус                    226411 non-null  object
#  12  Расстояние до центра, км  13036 non-null   float64
# ...
