# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Млн\Первичка-Млн_06-26_для БД.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Формат   29 non-null     object
#  1   Спальни  29 non-null     object
# dtypes: object(2)
# memory usage: 596.0+ bytes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239400 entries, 0 to 239399
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Дата              0 non-null       float64
#  1   Название проекта  239400 non-null  object
#  2   Девелопер         239400 non-null  object
#  3   Класс             0 non-null       float64
#  4   Локация           239400 non-null  object
#  5   Город             239400 non-null  object
#  6   Метро             95043 non-null   object
#  7   Срок сдачи        239210 non-null  object
#  8   Тип помещения     239400 non-null  object
#  9   Отделка           239400 non-null  object
#  10  Кол-во комнат     239400 non-null  int64
#  11  Площадь, кв.м     239400 non-null  float64
#  12  Цена лота, руб.   239400 non-null  int64
#  13  Этаж              239400 non-null  int64
# dtypes: float64(3), int64(3), object(8)
# memory usage: 25.6+ MB

# %%
df = df.drop(['Ссылка', 'Район', 'Округ', 'Год сдачи'], axis=1, errors='ignore')

# %%
df['Тип помещения'].unique()
# Out:
# <StringArray>
# ['Квартиры', 'Апартаменты', 'Квартира']
# Length: 3, dtype: str

# %%
df['Тип помещения'].value_counts()
# Out:
# Тип помещения
# Квартиры       233667
# Апартаменты      6486
# Name: count, dtype: int64

# %%
df['Тип помещения'] = df['Тип помещения'].replace('Квартира', 'Квартиры')
df['Тип помещения'] = df['Тип помещения'].replace('апартаменты', 'Апартаменты')

# %%
df['Дата'].unique()
# Out:
# <DatetimeArray>
# ['2026-06-30 00:00:00']
# Length: 1, dtype: datetime64[us]

# %%
df['Дата'].value_counts()
# Out:
# Дата
# 2026-06-30    240153
# Name: count, dtype: int64

# %%
df = df[~df['Дата обновления'].isin(['2025-03-04', '2025-01-01'])]

# %%
df['Дата'] = pd.to_datetime('30.06.2026', format='%d.%m.%Y')

# %%
df['Срок сдачи'].unique()
# Out:
# <StringArray>
# ['3 квартал 2028 года',            'Дом сдан', '4 квартал 2028 года',
#  '4 квартал 2027 года', '2 квартал 2027 года', '4 квартал 2026 года',
#  '2 квартал 2030 года', '4 квартал 2029 года', '2 квартал 2026 года',
#  '3 квартал 2026 года', '2 квартал 2028 года', '1 квартал 2027 года',
#  '2 квартал 2029 года', '3 квартал 2027 года',                   nan,
#  '3 квартал 2029 года', '1 квартал 2029 года', '1 квартал 2028 года',
#  '4 квартал 2031 года', '4 квартал 2025 года', '2 квартал 2025 года',
#  '4 квартал 2024 года', '1 квартал 2025 года', '1 квартал 2030 года',
#  '1 квартал 2026 года', '3 квартал 2025 года', '4 квартал 2023 года',
#  '3 квартал 2030 года', '1 квартал 2024 года', '3 квартал 2020 года',
#  '4 квартал 2030 года', '2 квартал 2024 года', '1 квартал 2023 года',
#  '1 квартал 2022 года', '1 квартал 2032 года', '2 квартал 2022 года',
#  '1 квартал 2021 года', '3 квартал 2024 года', '3 квартал 2023 года',
#  '4 квартал 2020 года', '4 квартал 2019 года', '3 квартал 2032 года',
#  '3 квартал 2031 года', '3 квартал 2018 года', '2 квартал 2023 года',
#  '2 квартал 2021 года']
# Length: 46, dtype: str

# %%
df['Срок сдачи'] = df['Срок сдачи'].str.replace(',', '')

# %%
df['Название проекта'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Девелопер'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Отделка'].value_counts()
# Out:
# Отделка
# Без отделки                 98642
# Предчистовая                97066
# С отделкой                  43218
# С отделкой и доп опциями     1227
# Name: count, dtype: int64

# %%
df['Кол-во комнат'].value_counts()
# Out:
# Кол-во комнат
# 1         87925
# 2         76753
# 3         39263
# Студия    20179
# 0         12526
# 4          3325
# 5           161
# 6            21
# Name: count, dtype: int64

# %%
df['Цена лота, руб.'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Цена лота, руб.'].unique()
# Out:
# array([14720000, 15127376, 15213488, ..., 8596596, 8691064, 8785532],
#       shape=(88311,), dtype=object)

# %%
city_to_region = {
    'Волгоград': 'Волгоградская область',
    'Воронеж': 'Воронежская область',
    'Екатеринбург': 'Свердловская область',
    'Казань': 'Республика Татарстан',
    'Краснодар': 'Краснодарский край',
    'Красноярск': 'Красноярский край',
    'Нижний Новгород': 'Нижегородская область',
    'Новосибирск': 'Новосибирская область',
    'Омск': 'Омская область',
    'Пермь': 'Пермский край',
    'Ростов-на-Дону': 'Ростовская область',
    'Самара': 'Самарская область',
    'Санкт-Петербург': 'Ленинградская область',
    'Уфа': 'Республика Башкортостан',
    'Челябинск': 'Челябинская область'
}

# Создаем пустой столбец Локация
df['Локация'] = None

# Заполняем его по соответствию с Городом
df['Локация'] = df['Город'].map(city_to_region)

# %%
df['Класс'] = None

# %%
df['Этаж'] = None

# %%
new_order = [
    'Дата',
    'Название проекта',
    'Девелопер',
    'Класс',
    'Локация',
    'Город',
    'Метро',
    'Срок сдачи',
    'Тип помещения',
    'Отделка',
    'Кол-во комнат',
    'Площадь, кв.м',
    'Цена лота, руб.',
    'Этаж'
]

# Применяем порядок
df = df[new_order]

# %%
df.to_csv(r"C:\Млн\Первичка-Млн_06-26_для БД.csv", index=False)
