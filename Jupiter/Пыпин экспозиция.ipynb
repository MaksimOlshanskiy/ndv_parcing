# %%
import os
import glob
import pandas as pd

# Путь к папке, где находятся Excel файлы
folder_path = r"D:\Ricci\Экспозиция"

# Создаём пустой DataFrame для накопления данных
all_data = pd.DataFrame()

# Используем glob для поиска всех Excel файлов в папке
excel_files = glob.glob(os.path.join(folder_path, "*.xlsx"))

# Проходим по каждому файлу и добавляем его данные в DataFrame
for file_path in excel_files:
    try:
        df = pd.read_excel(file_path)  # Читаем Excel файл в DataFrame
    except:
        print(file_path)
    df.columns = df.columns.str.capitalize()


    all_data = pd.concat([all_data, df], ignore_index=True)  # Добавляем данные в общий DataFrame

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359017 entries, 0 to 2359016
# Data columns (total 45 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Id корпуса                int64
#  1   Id жк                     int64
#  2   Жк рус                    object
#  3   Жк англ                   object
#  4   Корпус                    object
#  5   Кр корпус                 object
#  6   Регион                    object
#  7   Id кв                     int64
#  8   Дата актуализации         object
#  9   Комнат                    float64
#  10  Площадь                   float64
#  11  Цена                      float64
#  12  Цена кв м                 float64
#  13  Этаж                      object
#  14  Номер на этаже            float64
#  15  Номер в корпусе           object
#  16  Номер секции              object
#  17  Адрес корп                object
#  18  Lat                       float64
#  19  Lng                       float64
#  20  Район город               object
#  21  Округ направление         object
#  22  Атд                       object
#  23  Источник                  object
#  24  Тип корпуса               object
#  25  Класс к                   object
#  26  Тип кв/ап                 object
#  27  Застройщик                object
#  28  Тип помещения             object
#  29  Отделка помещения         object
#  30  Отделка к                 object
#  31  Договор к                 object
#  32  Сдача к                   object
#  33  Стадия к                  object
#  34  Цена со скидкой           float64
#  35  Зона                      object
#  36  Отделка текст             object
#  37  Старт продаж к            float64
#  38  Изменение цены последнее  float64
#  39  Экспозиция                float64
#  40  Изменение цены            float64
#  41  Жилая площадь             float64
#  42  Площадь кухни             float64
#  43  Id дом.рф                 float64
#  44  Высота потолков           float64
# dtypes: float64(16), int64(3), object(26)
# memory usage: 809.9+ MB

# %%
all_data['Дата актуализации'].unique()
# Out:
# <DatetimeArray>
# ['2025-11-01 00:00:00', '2025-04-01 00:00:00', '2025-04-02 00:00:00',
#  '2026-04-01 00:00:00', '2025-06-01 00:00:00', '2025-06-02 00:00:00',
#  '2026-06-01 00:00:00', '2026-06-02 00:00:00', '2025-07-01 00:00:00',
#  '2025-07-02 00:00:00', '2025-09-01 00:00:00', '2025-08-31 00:00:00',
#  '2025-10-01 00:00:00', '2025-12-01 00:00:00', '2026-02-01 00:00:00',
#  '2026-02-02 00:00:00', '2026-02-03 00:00:00', '2026-03-03 00:00:00',
#  '2026-03-01 00:00:00', '2026-03-02 00:00:00', '2025-08-01 00:00:00',
#  '2025-05-03 00:00:00', '2025-05-04 00:00:00', '2026-05-03 00:00:00',
#  '2026-05-04 00:00:00', '2026-01-10 00:00:00', '2026-01-11 00:00:00',
#  '2025-03-17 00:00:00', '2025-03-18 00:00:00']
# Length: 29, dtype: datetime64[ns]

# %%
all_data['Дата актуализации'] = pd.to_datetime(
    all_data['Дата актуализации'],
    dayfirst=True
)
# Out:
#     Год  Месяц  Количество строк
# 0  2025      4             14168
# 1  2025     11            144461

# %%
result = (
    all_data.groupby(all_data['Дата актуализации'].dt.to_period('M'))
      .size()
      .reset_index(name='Количество строк')
)

print(result)
# Out:
#    Дата актуализации  Количество строк
# 0            2025-03            158629
# 1            2025-04            157958
# 2            2025-05            158441
# 3            2025-06            157356
# 4            2025-07            162093
# 5            2025-08            162302
# 6            2025-09            156932
# 7            2025-10            151123
# 8            2025-11            144461
# 9            2025-12            137255
# 10           2026-01            134086
# 11           2026-02            131136
# 12           2026-03            135297
# 13           2026-04            134847
# 14           2026-05            135625
# 15           2026-06            141476

# %% [markdown]
# Удалим лишние столбцы

# %%
df.drop(
    columns=['Жк англ', 'Корпус', 'ID кв', 'Высота потолков', 'Класс К', 'Источник', 'Изменение цены последнее', 'Изменение цены', ],
    inplace=True,
    errors='ignore'
)
