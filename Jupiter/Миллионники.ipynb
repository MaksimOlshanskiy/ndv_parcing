# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv(r"C:\Users\m.olshanskiy\Desktop\Млн csv 2025.csv")
# Out:
# C:\Users\m.olshanskiy\AppData\Local\Temp\ipykernel_1020\2326514659.py:1: DtypeWarning: Columns (2,6,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\m.olshanskiy\Desktop\Млн csv 2025.csv")

# %%
df['month'].unique()
# Out:
# <PeriodArray>
# ['2025-04', '2025-05', '2025-06', '2025-07', '2025-08', '2025-09', '2025-10',
#  '2025-11', '2025-01', '2025-03', '2025-12']
# Length: 11, dtype: period[M]

# %%
df.loc[(df['month'] == '2025-12') & (df['Район'].isna()), 'Район'] = '-'

# %%
df.isna().sum()
# Out:
# Дата обновления           0
# Срок сдачи            16978
# Ссылка              1022123
# Название проекта          0
# Девелопер              1699
# Тип помещения             0
# Отделка              298616
# Кол-во комнат             0
# Площадь, кв.м             0
# Цена лота, руб.           0
# Город                     0
# Район                105826
# Год сдачи            268873
# Цена кв.м, руб.           0
# Округ               1774553
# Метро               2260420
# Микрорайон          2367562
# dtype: int64

# %%
df['Дата обновления'] = pd.to_datetime(df['Дата обновления'])
df['month'] = df['Дата обновления'].dt.to_period('M')
df.groupby('month').apply(lambda x: x.isna().sum())
# Out:
# C:\Users\m.olshanskiy\AppData\Local\Temp\ipykernel_1020\1242234531.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('month').apply(lambda x: x.isna().sum())
#          Дата обновления  Срок сдачи  Ссылка  Название проекта  Девелопер  \
# month
# 2025-01                0         251       0                 0       1322
# 2025-03                0           0       0                 0          0
# 2025-04                0       16537   27156                 0          0
# 2025-05                0           0  157430                 0          0
# 2025-06                0           0   25432                 0          0
# ...

# %%
df['Район'] = df.groupby(['Название проекта', 'Город'])['Район'].transform(
    lambda x: x.fillna(method='ffill').fillna(method='bfill')
)
# Out:
# C:\Users\m.olshanskiy\AppData\Local\Temp\ipykernel_1020\1368922450.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   lambda x: x.fillna(method='ffill').fillna(method='bfill')
# C:\Users\m.olshanskiy\AppData\Local\Temp\ipykernel_1020\1368922450.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   lambda x: x.fillna(method='ffill').fillna(method='bfill')

# %%
df['month'] = df['Дата обновления'].dt.to_period('M')
df.groupby('month').apply(lambda x: x.isna().sum())
# Out:
# C:\Users\m.olshanskiy\AppData\Local\Temp\ipykernel_1020\1444659556.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('month').apply(lambda x: x.isna().sum())
#          Дата обновления  Срок сдачи  Ссылка  Название проекта  Девелопер  \
# month
# 2025-01                0         251       0                 0       1322
# 2025-03                0           0       0                 0          0
# 2025-04                0       16537   27156                 0          0
# 2025-05                0           0  157430                 0          0
# 2025-06                0           0   25432                 0          0
# ...

# %%
df = pd.read_excel(r"C:\Users\m.olshanskiy\Desktop\Города млн\2025\Первичка\АПРЕЛЬ.xlsb")

# %%
df2 = pd.read_excel(r"C:\Users\m.olshanskiy\Desktop\Города млн\2025\Первичка\МАЙ.xlsx")

# %%
df3 = pd.read_excel(r"C:\Users\m.olshanskiy\Desktop\Города млн\2025\Первичка\ИЮНЬ.xlsb")

# %%
df4 = pd.read_excel(r"C:\Users\m.olshanskiy\Desktop\Города млн\2025\Первичка\ИЮЛЬ.xlsb")

# %%
df5 = pd.read_excel(r"C:\Users\m.olshanskiy\Desktop\Города млн\2025\Первичка\АВГУСТ.xlsb")

# %%
df6 = pd.read_excel(r"C:\Users\m.olshanskiy\Desktop\Города млн\2025\Первичка\СЕНТЯБРЬ.xlsb")

# %%
df7 = pd.read_excel(r"C:\Users\m.olshanskiy\Desktop\Города млн\2025\Первичка\ОКТЯБРЬ.xlsx")

# %%
df8 = pd.read_excel(r"C:\Users\m.olshanskiy\Desktop\Города млн\2025\Первичка\НОЯБРЬ.xlsb")

# %%
df_общий = pd.concat([df, df2, df3, df4, df5], ignore_index=True)

# %%
df_общий2 = pd.concat([df6, df7, df8], ignore_index=True)

# %%
df_общий3 = pd.concat([df_общий, df_общий2], ignore_index=True)

# %%
df_общий3 = df_общий3.drop(columns=['Паркинг'])

# %%
df_общий['Город'].unique()
# Out:
# array(['Санкт-Петербург', 'Екатеринбург', 'Новосибирск', 'Уфа', 'Казань',
#        'Ростов-на-Дону', 'Краснодар', 'Нижний Новгород', 'Пермь',
#        'Самара', 'Воронеж', 'Челябинск', 'Красноярск', 'Волгоград',
#        'Омск'], dtype=object)

# %%
df_общий = df_общий[df_общий['Город'] != 'Тюмень']

# Заменяем 'Ростов' на 'Ростов-на-Дону'
df_общий['Город'] = df_общий['Город'].replace('Ростов', 'Ростов-на-Дону')

# %%
df_общий3.
# Out:
#        Дата обновления                      Срок сдачи     Ссылка  \
# 0  2025-04-30 00:00:00  Cдача ГК: 4 квартал, 2026 года  305422886
# 1  2025-04-30 00:00:00  Cдача ГК: 4 квартал, 2026 года  305422879
# 2  2025-04-30 00:00:00  Cдача ГК: 4 квартал, 2026 года  305422907
# 3  2025-04-30 00:00:00  Cдача ГК: 4 квартал, 2026 года  305422985
# 4  2025-04-30 00:00:00  Cдача ГК: 4 квартал, 2026 года  316390466
#
#           Название проекта Девелопер Тип помещения      Отделка Кол-во комнат  \
# 0  17/33 Петровский остров   Element      Квартира  Без отделки             0
# 1  17/33 Петровский остров   Element      Квартира  Без отделки             0
# 2  17/33 Петровский остров   Element      Квартира  Без отделки             0
# 3  17/33 Петровский остров   Element      Квартира  Без отделки             0
# 4  17/33 Петровский остров   Element      Квартира  Без отделки             3
#
#    Площадь, кв.м Цена лота, руб.            Город Район Год сдачи  \
# ...

# %%
df_общий3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1925454 entries, 0 to 1925453
# Data columns (total 17 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Дата обновления   object
#  1   Срок сдачи        object
#  2   Ссылка            object
#  3   Название проекта  object
#  4   Девелопер         object
#  5   Тип помещения     object
#  6   Отделка           object
#  7   Кол-во комнат     object
#  8   Площадь, кв.м     float64
#  9   Цена лота, руб.   object
#  10  Город             object
#  11  Район             object
#  12  Год сдачи         object
#  13  Балконы/лоджии    float64
#  14  Цена кв.м, руб.   float64
#  15  Округ             object
#  16  Метро             object
# dtypes: float64(3), object(14)
# memory usage: 249.7+ MB

# %%
df_общий.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1247167 entries, 0 to 1247221
# Data columns (total 15 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Дата обновления   1247167 non-null  datetime64[ns]
#  1   Срок сдачи        1211180 non-null  object
#  2   Ссылка            639614 non-null   object
#  3   Название проекта  1247146 non-null  object
#  4   Девелопер         1246769 non-null  object
#  5   Тип помещения     1219990 non-null  object
#  6   Отделка           1231112 non-null  object
#  7   Кол-во комнат     1238927 non-null  object
#  8   Площадь, кв.м     1247146 non-null  float64
#  9   Цена лота, руб.   1212677 non-null  object
#  10  Город             1247167 non-null  object
#  11  Район             246987 non-null   object
#  12  Год сдачи         1367 non-null     object
#  13  Балконы/лоджии    227937 non-null   float64
#  14  Паркинг           27392 non-null    object
# ...

# %%
df_общий.head()
# Out:
#   Дата обновления                      Срок сдачи     Ссылка  \
# 0      2025-04-30  Cдача ГК: 4 квартал, 2026 года  305422886
# 1      2025-04-30  Cдача ГК: 4 квартал, 2026 года  305422879
# 2      2025-04-30  Cдача ГК: 4 квартал, 2026 года  305422907
# 3      2025-04-30  Cдача ГК: 4 квартал, 2026 года  305422985
# 4      2025-04-30  Cдача ГК: 4 квартал, 2026 года  316390466
#
#           Название проекта Девелопер Тип помещения      Отделка Кол-во комнат  \
# 0  17/33 Петровский остров   Element      Квартира  Без отделки             0
# 1  17/33 Петровский остров   Element      Квартира  Без отделки             0
# 2  17/33 Петровский остров   Element      Квартира  Без отделки             0
# 3  17/33 Петровский остров   Element      Квартира  Без отделки             0
# 4  17/33 Петровский остров   Element      Квартира  Без отделки             3
#
#    Площадь, кв.м Цена лота, руб.            Город Район Год сдачи  \
# ...

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222401 entries, 0 to 222400
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Дата обновления           180 non-null     float64
#  1   Название проекта          222401 non-null  object
#  2   Девелопер                 222401 non-null  object
#  3   Город                     222401 non-null  object
#  4   Район                     222401 non-null  object
#  5   Гео3                      221301 non-null  object
#  6   Расстояние до центра, км  220470 non-null  float64
#  7   Срок сдачи                222186 non-null  object
#  8   Тип помещения             222401 non-null  object
#  9   Отделка                   222401 non-null  object
#  10  Кол-во комнат             222399 non-null  float64
#  11  Площадь, кв.м             222401 non-null  float64
#  12  Цена лота, руб.           222401 non-null  int64
# ...

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242051 entries, 0 to 242050
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Дата обновления   242051 non-null  datetime64[ns]
#  1   Название проекта  242051 non-null  object
#  2   Девелопер         242051 non-null  object
#  3   Город             242051 non-null  object
#  4   Район             242051 non-null  object
#  5   Срок сдачи        241796 non-null  object
#  6   Тип помещения     242051 non-null  object
#  7   Отделка           242051 non-null  object
#  8   Кол-во комнат     242051 non-null  int64
#  9   Площадь, кв.м     242051 non-null  float64
#  10  Цена кв.м, руб.   242051 non-null  float64
#  11  Цена лота, руб.   242051 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(7)
# memory usage: 22.2+ MB

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213835 entries, 0 to 213834
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Дата обновления           213835 non-null  datetime64[ns]
#  1   Название проекта          213835 non-null  object
#  2   Девелопер                 213835 non-null  object
#  3   Город                     213835 non-null  object
#  4   Округ                     64682 non-null   object
#  5   Район                     173054 non-null  object
#  6   Метро                     92695 non-null   object
#  7   Расстояние до центра, км  213835 non-null  float64
#  8   Срок сдачи                213523 non-null  object
#  9   Тип помещения             213835 non-null  object
#  10  Отделка                   213820 non-null  object
#  11  Кол-во комнат             213835 non-null  object
#  12  Площадь, кв.м             213835 non-null  float64
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264409 entries, 0 to 264408
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Дата обновления   264409 non-null  datetime64[ns]
#  1   Срок сдачи        263888 non-null  object
#  2   Ссылка            65439 non-null   object
#  3   Название проекта  264388 non-null  object
#  4   Девелопер         264388 non-null  object
#  5   Адрес             264409 non-null  object
#  6   Корпус            233688 non-null  object
#  7   Тип помещения     264388 non-null  object
#  8   Отделка           263427 non-null  object
#  9   Кол-во комнат     264378 non-null  float64
#  10  Площадь, кв.м     264388 non-null  float64
#  11  Цена лота, руб.   264388 non-null  object
#  12  Этаж              257722 non-null  float64
#  13  Дата объявления   233688 non-null  object
#  14  Город             264409 non-null  object
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 252441 entries, 0 to 254861
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Дата обновления           252441 non-null  datetime64[ns]
#  1   Название проекта          252441 non-null  object
#  2   Девелопер                 252064 non-null  object
#  3   Область                   252441 non-null  object
#  4   Город                     252441 non-null  object
#  5   Район                     241882 non-null  object
#  6   Гео4                      229390 non-null  object
#  7   Корпус                    228245 non-null  object
#  8   Расстояние до центра, км  250843 non-null  float64
#  9   Срок сдачи                251805 non-null  object
#  10  Год сдачи                 1367 non-null    object
#  11  Тип помещения             252441 non-null  object
#  12  Отделка                   252432 non-null  object
# ...

# %%
df8.columns = df8.columns.str.lower().str.capitalize()

# %%
df6.head()
# Out:
#    Дата обновления Название проекта  Девелопер   Город           Район Гео3  \
# 0          45930.0          СПУТНИК  Новый Дон  Самара     Октябрьский  NaN
# 1          45930.0         Классики   РАЗВИТИЕ  Самара    улица Победы  14а
# 2          45930.0     Новая Самара   ФИНСТРОЙ  Самара  Красноглинский  NaN
# 3          45930.0     Новая Самара   ФИНСТРОЙ  Самара  Красноглинский  NaN
# 4          45930.0     Новая Самара   ФИНСТРОЙ  Самара  Красноглинский  NaN
#
#    Расстояние до центра, км           Срок сдачи Тип помещения      Отделка  \
# 0                      7.21  2 квартал 2028 года      Квартира  Без отделки
# 1                      8.11  4 квартал 2029 года      Квартира  Без отделки
# 2                     17.84  3 квартал 2027 года      Квартира  Без отделки
# 3                     17.84  3 квартал 2027 года      Квартира  Без отделки
# 4                     17.84  3 квартал 2027 года      Квартира  Без отделки
#
# ...

# %%
df['Тип помещения'] = (
    df['Тип помещения']
    .str.strip()
    .replace('квартиры', 'Квартира')
)
df2['Тип помещения'] = (
    df2['Тип помещения']
    .str.strip()
    .replace('квартиры', 'Квартира')
)
df3['Тип помещения'] = (
    df3['Тип помещения']
    .str.strip()
    .replace('квартиры', 'Квартира')
)
df4['Тип помещения'] = (
    df4['Тип помещения']
    .str.strip()
    .replace('квартиры', 'Квартира')
)
df5['Тип помещения'] = (
    df5['Тип помещения']
    .str.strip()
    .replace('квартиры', 'Квартира')
)

# %%
df_общий3['Дата обновления'] = pd.to_datetime('1899-12-30') + pd.to_timedelta(df_общий3['Дата обновления'], unit='D')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File timedeltas.pyx:438, in pandas._libs.tslibs.timedeltas.array_to_timedelta64()
#
# File timedeltas.pyx:470, in pandas._libs.tslibs.timedeltas._item_to_timedelta64_fastpath()
#
# TypeError: Expected unicode, got Timestamp
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 df_общий3['Дата обновления'] = pd.to_datetime('1899-12-30') + pd.to_timedelta(df_общий3['Дата обновления'], unit='D')
#
# File ~\PycharmProjects\ndv_parsing\.venv\Lib\site-packages\pandas\core\tools\timedeltas.py:201, in to_timedelta(arg, unit, errors)
#     199     return arg
#     200 elif isinstance(arg, ABCSeries):
# --> 201     values = _convert_listlike(arg._values, unit=unit, errors=errors)
# ...

# %%
df3.rename(columns={'Регион': 'Город'}, inplace=True)

# %%
df5 = df5.drop(columns=['Класс'])

# %%
df5 = df5[~(
    (df5['Область'] == 'Республика Башкортостан') &
    (df5['Город'] != 'Уфа')
)]
df5 = df5[~(
    (df5['Область'] == 'Республика Татарстан') &
    (df5['Город'] != 'Казань')
)]
df5 = df5[~(
    (df5['Область'] == 'Ростовская область') &
    (df5['Город'] != 'Ростов-на-Дону')
)]
df5 = df5[~(
    (df5['Область'] == 'Челябинская область') &
    (df5['Город'] != 'Челябинск')
)]

# %%
df5 = df5[df5['Область'] != 'Самарская область']

# %%
df5.loc[df5['Область'] == 'Самара', 'Город'] = 'Самара'

# %%
mask = df5['Область'] == 'Санкт-Петербург'

# переносим Город → Район
df5.loc[mask, 'Район'] = df5.loc[mask, 'Город']

# ставим единое значение в Город
df5.loc[mask, 'Город'] = 'Санкт-Петербург'

# %%
mask = df5['Область'] == 'Уфа'

# переносим Город → Район
df5.loc[mask, 'Район'] = df5.loc[mask, 'Город']

# ставим единое значение в Город
df5.loc[mask, 'Город'] = 'Уфа'

# %%
df['Ссылка'] = df['Ссылка'].str.rstrip('/').str.split('/').str[-1]
df2['Ссылка'] = df2['Ссылка'].str.rstrip('/').str.split('/').str[-1]
df3['Ссылка'] = df3['Ссылка'].str.rstrip('/').str.split('/').str[-1]
df4['Ссылка'] = df4['Ссылка'].str.rstrip('/').str.split('/').str[-1]
df5['Ссылка'] = df5['Ссылка'].str.rstrip('/').str.split('/').str[-1]

# %%
df6['Ссылка'] = df6['Ссылка'].str.rstrip('/').str.split('/').str[-1]
df7['Ссылка'] = df7['Ссылка'].str.rstrip('/').str.split('/').str[-1]

# %%
df_общий3.to_csv(r"C:\Users\m.olshanskiy\Desktop\Города млн\2025\Первичка\2025.csv", index=False, encoding='utf-8')
