# %%
import pandas as pd

# %%
df = pd.read_excel(r"D:\Ricci\Коммерция\08.2026\Ритейл_08-26_light.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Дата обновления                 1276 non-null   datetime64[ns]
#  1   Название проекта                1276 non-null   object
#  2   Местоположение                  1232 non-null   object
#  3   Метро                           1232 non-null   object
#  4   Расстояние до метро, км         1232 non-null   object
#  5   Время до метро, мин             1232 non-null   object
#  6   МЦК/МЦД                         1183 non-null   object
#  7   Расстояние до МЦК/МЦД, км       1189 non-null   object
#  8   Время до МЦК/МЦД, мин           1141 non-null   object
#  9   БКЛ                             1232 non-null   object
#  10  Расстояние до БКЛ, км           1232 non-null   object
#  11  Время до БКЛ, мин               1232 non-null   object
# ...

# %%
df2 = pd.read_excel(r"D:\Ricci\Ricci_classes.xlsx")

# %%
df = df.merge(
    df2[['Название проекта', 'ricci_class']],
    on='Название проекта',
    how='left'
)

# %%
df.to_excel('Commerce_with_classes.xlsx', index=False)
