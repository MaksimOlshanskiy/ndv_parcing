# %%
import pandas as pd

# %%
df1 = pd.read_excel(r"C:\Users\m.olshanskiy\PycharmProjects\ndv_parsing\НашДомРФ\Продажи\Продажи_Калининград.xlsx")

# %%
df2 = pd.read_excel(r"C:\Users\m.olshanskiy\PycharmProjects\ndv_parsing\НашДомРФ_Кал\2026-03-10\Мо_НашДомРФ_2026-03-10.xlsx")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1568 entries, 0 to 1567
# Data columns (total 32 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Название проекта_x                           0 non-null      float64
#  1   Корпус                                       0 non-null      float64
#  2   Id дом.рф                                    1568 non-null   int64
#  3   Дата декларации                              1568 non-null   datetime64[ns]
#  4   № проектной декларации                       1568 non-null   object
#  5   Жилые помещения, количество договоров        1568 non-null   int64
#  6   Жилые помещения, площадь объектов            1568 non-null   float64
#  7   Жилые помещения, суммарная цена договоров    1568 non-null   float64
#  8   Нежилые помещения, количество договоров      1568 non-null   int64
# ...

# %%
df1 = df1.merge(
    df2[['id', 'Название проекта', 'Застройщик']],
    left_on='Id дом.рф',
    right_on='id',
    how='left'
)

df1 = df1.drop(columns='id')

# %%
df1.to_excel(r'C:\Users\m.olshanskiy\PycharmProjects\ndv_parsing\НашДомРФ\Продажи\Продажи_Калининград2.xlsx', index=False)
