# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Пыпин продажи\07-2026/realty_sold_06072026_M.xlsx')

# %%
df2 = pd.read_excel(r'C:\Пыпин продажи\07-2026/realty_sold_06072026_MO.xlsx')

# %%
df3 = pd.read_excel(r'C:\Пыпин продажи\07-2026/realty_sold_06072026_NM.xlsx')

# %%
df_общий = pd.concat([df, df2, df3], ignore_index=True)

# %%
df_общий.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2080971 entries, 0 to 2080970
# Data columns (total 62 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   ID ЖК                            float64
#  1   ЖК рус                           str
#  2   ЖК англ                          str
#  3   Район Город                      str
#  4   Округ Направление                str
#  5   Регион                           str
#  6   АТД                              str
#  7   Застройщик ЖК                    str
#  8   Описание помещения               str
#  9   Площадь                          float64
#  10  Комнатность                      float64
#  11  Тип Комнатности                  str
#  12  Этаж                             float64
#  13  Номер                            str
#  14  Тип помещения                    str
#  15  Корпус                           str
#  16  Покупатель ЮЛ                    str
# ...

# %%
df_coords = (
    df[['ID ЖК', 'lat', 'lng']]
    .drop_duplicates(subset='ID ЖК')
    .reset_index(drop=True)
)

# %%
df_coords.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID ЖК   594 non-null    int64
#  1   lat     594 non-null    float64
#  2   lng     594 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 14.1 KB

# %%
df_coords.to_csv('coords.csv', index=False)
